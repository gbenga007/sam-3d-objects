# %% [markdown]
# # Metric Scale Analysis — v3 Heldout Evaluation
#
# Two-stage analysis of metric scale prediction on the 64-sample live heldout set.
#
# **Stage 1**: Direct MetricScaleDecoder output — predicted [W, H, D] vs GT [W, H, D], per-dimension error.
# **Stage 2**: Mesh bounding box accuracy — isotropic scaling (production) vs per-axis rank-matched scaling (upper bound). Quantifies the cost of wrong voxel aspect ratios from SS.

# %%
import os, sys
os.environ.setdefault('LIDRA_SKIP_INIT', '1')
os.environ.setdefault('ATTN_BACKEND', 'sdpa')
os.environ.setdefault('SPARSE_ATTN_BACKEND', 'sdpa')

# Run from repo root
REPO_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)
os.chdir(REPO_ROOT)
print('Working dir:', os.getcwd())
# Out:
# Working dir: /mnt/source/sam-3d-objects

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
from tqdm.notebook import tqdm
from torch.utils.data import Subset

from sam3d_objects.data.dataset.metric.nocs import OmniNOCSReal275Dataset
from sam3d_objects.model.backbone.metric_scale_decoder import MetricScaleDecoder
from sam3d_objects.model.backbone.scale_head import (
    MetricScaleHead, _ScaleAugmentedEmbedderProxy, extract_ss_scale_features,
)
from sam3d_objects.training.finetune_metric_scale import freeze_pipeline, load_metric_checkpoint

print('Imports OK')
# Out:
# Imports OK

# %% [markdown]
# ## Configuration
# Edit `CHECKPOINT` to switch between checkpoints (v3_best, ss_ratio_v1_best, etc.).

# %%
CHECKPOINT    = 'artifacts/metric_scale/checkpoints/nocs_sceneholdout_slat_conditioned_v3_best.pt'
CONFIG        = 'checkpoints/hf/pipeline.yaml'
ANNOTATIONS   = '/mnt/source/datasets_sam3d/OmniNOCS/omninocs_release_nocs_real275'
RGB_ROOT      = '/mnt/source/datasets_sam3d/OmniNOCS/real_test'
STAGE1_STEPS  = 4
STAGE2_STEPS  = 1
HELDOUT_N     = 64     # must match training --heldout-samples
DEVICE        = 'cuda'

# Category colour palette
CATEGORY_COLORS = {
    'bottle': '#e41a1c',
    'bowl':   '#377eb8',
    'camera': '#4daf4a',
    'can':    '#ff7f00',
    'cup':    '#984ea3',
    'laptop': '#a65628',
}

# %% [markdown]
# ## Load Pipeline, Heads, Dataset

# %%
from hydra.utils import instantiate
from omegaconf import OmegaConf

print('Loading pipeline...')
config = OmegaConf.load(CONFIG)
config.workspace_dir = os.path.dirname(CONFIG)
config.compile_model = False
config.device = DEVICE
pipeline = instantiate(config)
freeze_pipeline(pipeline)
print('Pipeline loaded.')

scale_head    = MetricScaleHead().to(DEVICE).eval()
scale_decoder = MetricScaleDecoder().to(DEVICE).eval()
load_metric_checkpoint(CHECKPOINT, scale_head, scale_decoder)
print(f'Checkpoint loaded: {CHECKPOINT}')
# Out:
# Loading pipeline...
# 2026-05-14 19:26:34.758 | INFO     | sam3d_objects.pipeline.inference_pipeline:set_attention_backend:17 - GPU name is NVIDIA A100-SXM4-80GB
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# 2026-05-14 19:26:42.049 | INFO     | sam3d_objects.model.backbone.tdfy_dit.modules.sparse:__from_env:39 - [SPARSE] Backend: spconv, Attention: sdpa
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:51: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   _TORCH_CUSTOM_FWD = amp.custom_fwd(cast_inputs=torch.float16)
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:100: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:166: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:246: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:335: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:372: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:392: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:415: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# 2026-05-14 19:26:47.684 | INFO     | sam3d_objects.model.backbone.tdfy_dit.modules.attention:__from_env:30 - [ATTENTION] Using backend: sdpa
# [SPARSE][CONV] spconv algo: auto
# 2026-05-14 19:26:51.808 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# 2026-05-14 19:26:51.809 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# 2026-05-14 19:26:52.055 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/moge/model/v1.py:171: UserWarning: The following deprecated/invalid arguments are ignored: {'output_mask': True, 'split_head': True}
#   warnings.warn(f"The following deprecated/invalid arguments are ignored: {deprecated_kwargs}")
# 2026-05-14 19:27:11.704 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# 2026-05-14 19:27:11.708 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:102 - self.device: cuda
# 2026-05-14 19:27:11.708 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:103 - CUDA_VISIBLE_DEVICES: None
# 2026-05-14 19:27:11.709 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:104 - Actually using GPU: 0
# 2026-05-14 19:27:11.709 | INFO     | sam3d_objects.pipeline.inference_pipeline:init_pose_decoder:299 - Using pose decoder: ScaleShiftInvariant
# 2026-05-14 19:27:11.709 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:135 - Loading model weights...
# 2026-05-14 19:27:15.276 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/ss_generator.ckpt
# 2026-05-14 19:29:33.097 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/slat_generator.ckpt
# 2026-05-14 19:31:12.475 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/ss_decoder.ckpt
# 2026-05-14 19:31:16.462 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/slat_decoder_gs.ckpt
# 2026-05-14 19:31:21.114 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/slat_decoder_gs_4.ckpt
# 2026-05-14 19:31:27.491 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/slat_decoder_mesh.ckpt
# 2026-05-14 19:31:30.907 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-05-14 19:31:33.745 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-05-14 19:31:33.769 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-05-14 19:31:40.221 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-05-14 19:31:40.291 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/ss_generator.ckpt
# 2026-05-14 19:31:52.784 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-05-14 19:31:54.887 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-05-14 19:31:54.898 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-05-14 19:31:57.870 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-05-14 19:31:57.881 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/slat_generator.ckpt
# 2026-05-14 19:32:05.692 | INFO     | sam3d_objects.pipeline.inference_pipeline:override_ss_generator_cfg_config:440 - ss_generator parameters: inference_steps=25, cfg_strength=7, cfg_interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:32:05.697 | INFO     | sam3d_objects.pipeline.inference_pipeline:override_slat_generator_cfg_config:462 - slat_generator parameters: inference_steps=25, cfg_strength=1, cfg_interval=[0, 500], rescale_t=1
# 2026-05-14 19:32:05.699 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:200 - Loading model weights completed!
# Pipeline loaded.
# Loaded metric scale checkpoint from artifacts/metric_scale/checkpoints/nocs_sceneholdout_slat_conditioned_v3_best.pt
# Checkpoint loaded: artifacts/metric_scale/checkpoints/nocs_sceneholdout_slat_conditioned_v3_best.pt

# %%
# Replicate the training heldout split:
# --split-group record --heldout-samples 64 --seed 0 (no --shuffle-split)
# => heldout = last 64 records in dataset order

full_dataset = OmniNOCSReal275Dataset(
    annotations_root=ANNOTATIONS,
    rgb_root=RGB_ROOT,
    split='train',
    min_mask_pixels=500,
)
n = len(full_dataset)
heldout_indices = list(range(n - HELDOUT_N, n))
heldout_dataset = Subset(full_dataset, heldout_indices)
print(f'Full dataset: {n}  |  Heldout: {len(heldout_dataset)} samples')
# Out:
# Full dataset: 16118  |  Heldout: 64 samples

# %% [markdown]
# ## Run Inference on All 64 Heldout Samples
#
# Collects per-sample:
# - `pred_dims`: raw MetricScaleDecoder output [W, H, D] in metres
# - `gt_dims`: ground-truth [W, H, D] in metres
# - `verts_canonical`: mesh vertices in unit-cube canonical space
# - `faces`: triangle indices

# %%
import torch.nn.functional as F

def run_sample(item):
    """Returns a results dict for one heldout sample."""
    image   = item['image']             # np [H,W,4] uint8
    gt_dims = np.array(item['metric_dims'], dtype=np.float32)  # [W, H, D]
    category = item.get('category', 'unknown')

    with torch.no_grad():
        # --- Depth / conditioning ---
        pointmap_dict   = pipeline.compute_pointmap(image)
        ss_input_dict   = pipeline.preprocess_image(
            image, pipeline.ss_preprocessor,
            pointmap=pointmap_dict['pointmap'])
        slat_input_dict = pipeline.preprocess_image(image, pipeline.slat_preprocessor)

        # --- Stage 1: SS ---
        ss_ret = pipeline.sample_sparse_structure(
            ss_input_dict, inference_steps=STAGE1_STEPS, use_distillation=False)

        # --- Metric scale token ---
        ss_feats = extract_ss_scale_features(ss_ret)
        if ss_feats is not None:
            ss_feats = ss_feats.to(DEVICE)
        scale_token = scale_head(
            ss_ret['shape'],
            ss_feats,
            ss_input_dict.get('pointmap_scale'),
            ss_input_dict.get('pointmap_shift'),
        )

        # --- Inject into SLAT conditioning ---
        token_norm   = F.layer_norm(scale_token, [scale_token.shape[-1]])
        slat_backbone = pipeline._get_slat_backbone()
        orig_bb_emb  = orig_ext_emb = None
        if slat_backbone is not None:
            orig_bb_emb = slat_backbone.condition_embedder
            slat_backbone.condition_embedder = _ScaleAugmentedEmbedderProxy(orig_bb_emb, token_norm)
        cond_embs = getattr(pipeline, 'condition_embedders', {})
        orig_ext_emb = cond_embs.get('slat_condition_embedder')
        if orig_ext_emb is not None:
            pipeline.condition_embedders['slat_condition_embedder'] = \
                _ScaleAugmentedEmbedderProxy(orig_ext_emb, token_norm)

        try:
            slat = pipeline.sample_slat(
                slat_input_dict, ss_ret['coords'],
                inference_steps=STAGE2_STEPS, use_distillation=False)
        finally:
            if orig_bb_emb is not None and slat_backbone is not None:
                slat_backbone.condition_embedder = orig_bb_emb
            if orig_ext_emb is not None:
                pipeline.condition_embedders['slat_condition_embedder'] = orig_ext_emb

        # --- Decode mesh ---
        decoded    = pipeline.decode_slat(slat, formats=['mesh'])
        mesh       = decoded['mesh'][0]

        # --- Metric prediction [W, H, D] ---
        log_dims   = scale_decoder(slat.feats, scale_token, slat.coords[:, 0])
        pred_dims  = torch.exp(log_dims[0]).cpu().numpy()  # [3] W,H,D

    verts = mesh.vertices.float().cpu().numpy()  # [N, 3]
    faces = mesh.faces.int().cpu().numpy()        # [F, 3]

    return {
        'category':       category,
        'gt_dims':        gt_dims,          # [W, H, D] metres
        'pred_dims':      pred_dims,        # [W, H, D] metres
        'verts_canonical': verts,
        'faces':           faces,
    }

print('run_sample defined')
# Out:
# run_sample defined

# %%
results = []
skipped = 0

for i in tqdm(range(len(heldout_dataset)), desc='Running inference'):
    item = heldout_dataset[i]
    try:
        r = run_sample(item)
        results.append(r)
    except Exception as e:
        print(f'  [skip {i}] {e}')
        skipped += 1

print(f'\nDone. {len(results)} samples collected, {skipped} skipped.')
# Out:
# Running inference:   0%|          | 0/64 [00:00<?, ?it/s]
# 2026-05-14 19:34:03.514 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:34:03.518 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:03.984 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:05.788 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 16058 to 13907
# 2026-05-14 19:34:05.847 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:34:05.851 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:05.960 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:08.984 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:34:21.058 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:34:21.060 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:21.188 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:22.823 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 14939 to 14923
# 2026-05-14 19:34:22.824 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:34:22.825 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:22.893 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:23.264 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:34:24.542 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:34:24.548 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:24.675 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:26.327 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 25890 to 21388
# 2026-05-14 19:34:26.336 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:34:26.338 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:26.459 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:27.379 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:34:29.289 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:34:29.291 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:29.419 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:30.893 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 21788 to 17403
# 2026-05-14 19:34:30.896 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:34:30.897 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:30.975 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:31.680 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:34:33.398 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:34:33.399 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:33.514 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:35.103 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 35864 to 31820
# 2026-05-14 19:34:35.106 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:34:35.107 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:35.215 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:36.428 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:34:39.812 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:34:39.818 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:39.977 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:41.586 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 11686 to 11685
# 2026-05-14 19:34:41.599 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:34:41.603 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:41.733 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:42.230 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:34:44.018 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:34:44.022 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:44.159 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:45.667 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 29490 to 23907
# 2026-05-14 19:34:45.671 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:34:45.673 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:45.787 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:46.627 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:34:49.091 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:34:49.093 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:49.222 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:50.350 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 16511 to 14935
# 2026-05-14 19:34:50.352 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:34:50.352 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:50.427 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:50.732 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:34:51.858 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:34:51.859 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:51.976 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:53.495 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 15585 to 12846
# 2026-05-14 19:34:53.497 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:34:53.498 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:53.574 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:54.105 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:34:55.703 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:34:55.705 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:55.833 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:57.133 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 27470 to 24700
# 2026-05-14 19:34:57.149 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:34:57.150 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:34:57.263 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:34:58.174 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:00.455 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:00.457 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:00.585 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:01.513 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 14804 to 12468
# 2026-05-14 19:35:01.516 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:01.517 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:01.590 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:01.906 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:02.967 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:02.969 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:03.098 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:04.502 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 28674 to 23578
# 2026-05-14 19:35:04.505 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:04.506 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:04.611 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:05.152 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:07.860 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:07.865 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:08.003 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:09.595 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 10215 to 10213
# 2026-05-14 19:35:09.600 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:09.601 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:09.716 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:10.195 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:12.303 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:12.314 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:12.497 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:14.028 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 19791 to 17118
# 2026-05-14 19:35:14.030 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:14.031 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:14.137 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:14.786 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:16.799 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:16.805 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:16.936 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:18.240 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 27315 to 25082
# 2026-05-14 19:35:18.244 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:18.246 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:18.356 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:19.265 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:21.616 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:21.617 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:21.745 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:22.764 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 9394 to 9390
# 2026-05-14 19:35:22.765 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:22.766 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:22.834 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:23.034 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:23.999 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:24.000 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:24.127 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:25.632 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 50110 to 28701
# 2026-05-14 19:35:25.633 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:25.634 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:25.702 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:26.751 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:29.531 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:29.533 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:29.754 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:31.273 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 42389 to 37477
# 2026-05-14 19:35:31.275 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:31.275 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:31.347 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:32.730 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:36.005 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:36.008 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:36.140 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:37.683 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 39717 to 29044
# 2026-05-14 19:35:37.687 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:37.689 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:37.794 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:38.794 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:41.311 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:41.313 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:41.430 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:42.528 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 19872 to 15431
# 2026-05-14 19:35:42.531 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:42.532 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:42.647 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:43.219 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:44.773 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:44.776 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:44.910 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:46.058 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 20785 to 13298
# 2026-05-14 19:35:46.064 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:46.065 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:46.190 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:46.532 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:48.120 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:48.123 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:48.238 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:49.488 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 30012 to 27442
# 2026-05-14 19:35:49.491 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:49.493 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:49.601 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:50.154 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:52.681 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:52.683 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:52.812 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:54.292 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 16861 to 16786
# 2026-05-14 19:35:54.293 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:54.294 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:54.363 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:54.698 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:35:56.434 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:35:56.435 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:56.567 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:58.170 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 22958 to 14662
# 2026-05-14 19:35:58.171 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:35:58.172 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:35:58.241 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:35:58.837 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:00.718 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:00.723 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:00.843 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:02.435 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 25878 to 20934
# 2026-05-14 19:36:02.442 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:02.443 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:02.523 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:03.295 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:05.317 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:05.318 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:05.426 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:06.998 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 34246 to 26896
# 2026-05-14 19:36:07.000 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:07.001 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:07.078 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:08.011 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:11.080 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:11.083 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:11.217 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:12.755 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 21783 to 19194
# 2026-05-14 19:36:12.761 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:12.763 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:12.874 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:13.579 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:15.714 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:15.726 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:15.861 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:17.399 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 8845 to 8845
# 2026-05-14 19:36:17.402 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:17.403 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:17.509 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:17.975 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:20.138 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:20.143 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:20.275 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:21.793 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 40804 to 33086
# 2026-05-14 19:36:21.798 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:21.799 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:21.904 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:22.852 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:25.227 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:25.235 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:25.320 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:26.515 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 29915 to 25192
# 2026-05-14 19:36:26.516 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:26.517 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:26.586 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:27.081 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:28.946 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:28.947 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:29.039 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:30.615 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 16512 to 13376
# 2026-05-14 19:36:30.616 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:30.617 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:30.686 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:31.233 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:32.628 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:32.633 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:32.754 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:34.408 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 27474 to 25682
# 2026-05-14 19:36:34.414 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:34.415 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:34.528 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:35.431 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:38.005 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:38.006 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:38.118 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:39.131 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 15748 to 15000
# 2026-05-14 19:36:39.133 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:39.134 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:39.205 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:39.772 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:41.179 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:41.182 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:41.304 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:42.621 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 8259 to 8020
# 2026-05-14 19:36:42.624 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:42.625 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:42.732 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:43.068 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:44.208 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:44.210 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:44.342 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:45.974 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 15575 to 13819
# 2026-05-14 19:36:45.976 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:45.977 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:46.076 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:46.412 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:47.733 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:47.734 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:47.859 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:49.384 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 21542 to 21386
# 2026-05-14 19:36:49.388 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:49.389 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:49.497 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:50.292 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:52.960 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:52.962 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:53.094 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:54.569 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 12601 to 12601
# 2026-05-14 19:36:54.571 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:54.571 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:54.638 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:55.215 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:36:57.016 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:36:57.018 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:57.138 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:58.710 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 16458 to 16424
# 2026-05-14 19:36:58.711 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:36:58.712 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:36:58.782 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:36:59.234 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:37:01.030 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:37:01.031 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:37:01.110 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:37:02.220 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 32773 to 30870
# 2026-05-14 19:37:02.221 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:37:02.221 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:37:02.289 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:37:03.323 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:37:06.166 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:37:06.172 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:37:06.300 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:37:07.252 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 12304 to 12303
# ...
# 2026-05-14 19:37:50.925 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:37:52.768 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:37:52.769 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:37:52.900 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:37:53.901 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 31405 to 30550
# 2026-05-14 19:37:53.905 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:37:53.907 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:37:54.050 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:37:55.093 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:37:58.164 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:37:58.166 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:37:58.298 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:37:59.932 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 20575 to 16940
# 2026-05-14 19:37:59.933 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:37:59.934 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:00.002 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:00.710 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:38:02.487 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:38:02.489 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:02.566 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:03.990 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 19254 to 16924
# 2026-05-14 19:38:03.991 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:38:03.991 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:04.062 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:04.569 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:38:06.283 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:38:06.284 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:06.411 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:07.425 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 14154 to 14137
# 2026-05-14 19:38:07.427 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:38:07.428 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:07.505 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:07.722 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:38:09.019 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:38:09.023 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:09.156 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:10.863 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 37769 to 28003
# 2026-05-14 19:38:10.872 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:38:10.875 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:10.981 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:12.043 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:38:14.849 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:38:14.852 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:14.982 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:16.043 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 18801 to 18734
# 2026-05-14 19:38:16.045 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:38:16.046 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:16.121 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:16.443 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:38:18.318 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:38:18.322 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:18.467 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:20.084 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 47454 to 33224
# 2026-05-14 19:38:20.091 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:38:20.093 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:20.184 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:21.305 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:38:23.957 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:38:23.963 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:24.106 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:25.785 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 15626 to 15616
# 2026-05-14 19:38:25.793 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:38:25.795 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:25.913 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:26.323 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:38:27.692 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:38:27.696 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:27.842 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:29.438 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 20073 to 19404
# 2026-05-14 19:38:29.446 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:38:29.449 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:29.577 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:30.326 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:38:31.931 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:38:31.933 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:32.060 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:33.551 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 18032 to 16758
# 2026-05-14 19:38:33.553 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:38:33.553 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:33.627 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:34.181 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:38:36.298 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:38:36.301 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:36.415 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:37.993 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 36128 to 29726
# 2026-05-14 19:38:37.995 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:38:37.995 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:38.089 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:39.140 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:38:42.104 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:38:42.108 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:42.239 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:43.749 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 26814 to 23177
# 2026-05-14 19:38:43.751 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:38:43.751 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:43.829 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:44.687 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-14 19:38:46.671 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-14 19:38:46.673 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:46.787 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:48.382 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 18426 to 13614
# 2026-05-14 19:38:48.385 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-14 19:38:48.386 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-14 19:38:48.492 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-14 19:38:48.991 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# Done. 64 samples collected, 0 skipped.

# %% [markdown]
# ---
# ## Stage 1 — MetricScaleDecoder: Predicted vs GT [W, H, D]
#
# The decoder outputs three values corresponding directly to GT W (width), H (height), D (depth) in metres.

# %%
# Build a flat DataFrame for Stage 1
rows = []
for r in results:
    for dim_idx, dim_name in enumerate(['W', 'H', 'D']):
        rows.append({
            'category':  r['category'],
            'dim':       dim_name,
            'gt':        r['gt_dims'][dim_idx],
            'pred':      r['pred_dims'][dim_idx],
            'abs_err':   abs(r['pred_dims'][dim_idx] - r['gt_dims'][dim_idx]),
            'pct_err':   abs(r['pred_dims'][dim_idx] - r['gt_dims'][dim_idx]) /
                         max(r['gt_dims'][dim_idx], 1e-6) * 100,
        })
df1 = pd.DataFrame(rows)

# Summary table
summary1 = df1.groupby('dim').agg(
    MAPE=('pct_err', 'mean'),
    Median_APE=('pct_err', 'median'),
    Mean_abs_cm=('abs_err', lambda x: x.mean() * 100),
).round(3)
print('=== Stage 1: Per-dimension prediction error ===')
print(summary1.to_string())

overall_mape = df1['pct_err'].mean()
print(f'\nOverall MAPE across W,H,D: {overall_mape:.3f}%')
# Out:
# === Stage 1: Per-dimension prediction error ===
#       MAPE  Median_APE  Mean_abs_cm
# dim
# D    5.230       2.033        0.608
# H    4.678       1.929        0.538
# W    7.425       2.815        0.978
#
# Overall MAPE across W,H,D: 5.778%

# %%
# --- Scatter: Predicted vs GT per dimension ---
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Stage 1: MetricScaleDecoder  —  Predicted vs GT dimension (metres)', fontsize=13)

for ax, dim_name in zip(axes, ['W', 'H', 'D']):
    sub = df1[df1['dim'] == dim_name]
    for cat, grp in sub.groupby('category'):
        col = CATEGORY_COLORS.get(cat, 'gray')
        ax.scatter(grp['gt'], grp['pred'], c=col, label=cat, alpha=0.75, s=50, edgecolors='none')
    lo = min(sub['gt'].min(), sub['pred'].min()) * 0.9
    hi = max(sub['gt'].max(), sub['pred'].max()) * 1.1
    ax.plot([lo, hi], [lo, hi], 'k--', lw=1, label='perfect')
    ax.set_xlabel(f'GT {dim_name} (m)')
    ax.set_ylabel(f'Pred {dim_name} (m)')
    mape = sub['pct_err'].mean()
    ax.set_title(f'{dim_name}  |  MAPE = {mape:.2f}%')
    ax.legend(fontsize=7, markerscale=0.9)
    ax.set_xlim(lo, hi)
    ax.set_ylim(lo, hi)
    ax.set_aspect('equal')

plt.tight_layout()
#plt.savefig('/mnt/source/sam-3d-objects/artifacts/metric_scale/eval_v3_notebook/stage1_scatter.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# --- Per-category MAPE breakdown (Stage 1) ---
cat_dim = df1.groupby(['category', 'dim'])['pct_err'].mean().unstack('dim').round(2)
cat_dim['mean'] = cat_dim.mean(axis=1).round(2)
print('=== Stage 1: Per-category MAPE (%) per dimension ===')
print(cat_dim.to_string())
# Out:
# === Stage 1: Per-category MAPE (%) per dimension ===
# dim          D     H      W  mean
# category
# bottle    5.34  4.90   4.31  4.85
# bowl      7.93  5.01   5.19  6.04
# camera    2.90  2.85  18.43  8.06
# can       2.55  8.74   9.23  6.84
# cup       7.22  3.27   5.81  5.43
# laptop    4.22  3.06   4.51  3.93

# %%
# --- Error distribution violin plots (Stage 1) ---
import matplotlib.ticker as ticker

fig, ax = plt.subplots(figsize=(9, 5))
dim_order = ['W', 'H', 'D']
data_by_dim = [df1[df1['dim'] == d]['pct_err'].values for d in dim_order]

parts = ax.violinplot(data_by_dim, positions=[1, 2, 3], showmedians=True, showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#4682b4')
    pc.set_alpha(0.6)

ax.set_xticks([1, 2, 3])
ax.set_xticklabels(['Width (W)', 'Height (H)', 'Depth (D)'])
ax.set_ylabel('Absolute percentage error (%)')
ax.set_title('Stage 1: Prediction error distribution per dimension')
ax.yaxis.set_minor_locator(ticker.AutoMinorLocator())
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
#plt.savefig('artifacts/metric_scale/eval_v3_notebook/stage1_violin.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# --- Aspect ratio accuracy: predicted ratio vs GT ratio ---
# Visualise how well the decoder captures the shape proportions (W:H, W:D)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle('Stage 1: Predicted aspect ratio vs GT aspect ratio')

for ax, (num_dim, den_dim) in zip(axes, [(0, 1), (0, 2)]):
    num_lbl = ['W', 'H', 'D'][num_dim]
    den_lbl = ['W', 'H', 'D'][den_dim]
    for r in results:
        cat = r['category']
        col = CATEGORY_COLORS.get(cat, 'gray')
        gt_ratio   = r['gt_dims'][num_dim]   / max(r['gt_dims'][den_dim],   1e-6)
        pred_ratio = r['pred_dims'][num_dim] / max(r['pred_dims'][den_dim], 1e-6)
        ax.scatter(gt_ratio, pred_ratio, c=col, alpha=0.7, s=50, edgecolors='none')
    lo = 0
    hi = max(ax.get_xlim()[1], ax.get_ylim()[1]) * 1.1
    ax.plot([lo, hi], [lo, hi], 'k--', lw=1)
    ax.set_xlabel(f'GT  {num_lbl}/{den_lbl}')
    ax.set_ylabel(f'Pred {num_lbl}/{den_lbl}')
    ax.set_title(f'{num_lbl} / {den_lbl} aspect ratio')

# Legend
patches = [mpatches.Patch(color=c, label=k) for k, c in CATEGORY_COLORS.items()]
axes[-1].legend(handles=patches, fontsize=8)
plt.tight_layout()
# plt.savefig('artifacts/metric_scale/eval_v3_notebook/stage1_aspect_ratio.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## Stage 2 — Mesh Bounding Box: Isotropic vs Per-Axis Scaling
#
# The canonical mesh has `max(bbox) ≈ 1.0` by construction (FlexiCubes).
# Two scaling strategies bring it into metric space:
#
# - **Isotropic** (production): `s = max(W_pred, H_pred, D_pred)` — all vertices × s
# - **Per-axis** (upper bound): rank-sort predicted dims descending, rank-sort mesh extents descending, scale each axis so its extent = corresponding predicted dim
#
# Both results are rank-sorted for comparison against GT (largest mesh extent ↔ largest GT dim).

# %%
def mesh_bbox_extents(verts):
    return verts.max(axis=0) - verts.min(axis=0)  # [3]

def apply_iso_scale(verts, pred_dims):
    s = pred_dims.max()
    return verts * s

def apply_peraxis_scale(verts, pred_dims):
    raw_ext  = mesh_bbox_extents(verts)          # [3] per-axis extents
    pred_sorted = np.sort(pred_dims)[::-1].copy() # [3] desc
    ext_rank    = np.argsort(raw_ext)[::-1]       # axis indices sorted by extent desc
    scale_factors = np.ones(3, dtype=np.float64)
    center = (verts.min(axis=0) + verts.max(axis=0)) / 2.0
    for rank, axis in enumerate(ext_rank):
        if raw_ext[axis] > 1e-6:
            scale_factors[axis] = pred_sorted[rank] / raw_ext[axis]
        else:
            scale_factors[axis] = 1.0
    return center + (verts - center) * scale_factors

# Compute Stage 2 metrics for all results
rows2 = []
for r in results:
    verts     = r['verts_canonical']
    pred_dims = r['pred_dims']
    gt_sorted = np.sort(r['gt_dims'])[::-1].copy()    # [3] desc

    # Isotropic
    v_iso   = apply_iso_scale(verts, pred_dims)
    ext_iso = np.sort(mesh_bbox_extents(v_iso))[::-1]  # [3] desc

    # Per-axis
    v_perax   = apply_peraxis_scale(verts, pred_dims)
    ext_perax = np.sort(mesh_bbox_extents(v_perax))[::-1]  # [3] desc

    for rank, rank_label in enumerate(['largest', 'middle', 'smallest']):
        rows2.append({
            'category': r['category'],
            'rank':     rank_label,
            'gt':       gt_sorted[rank],
            'iso':      ext_iso[rank],
            'peraxis':  ext_perax[rank],
            'iso_pct':    abs(ext_iso[rank]   - gt_sorted[rank]) / max(gt_sorted[rank], 1e-6) * 100,
            'peraxis_pct':abs(ext_perax[rank] - gt_sorted[rank]) / max(gt_sorted[rank], 1e-6) * 100,
        })

df2 = pd.DataFrame(rows2)

# Overall summary
# Per-sample MAPE (mean over 3 ranks)
per_sample_iso    = df2.groupby(df2.index // 3)['iso_pct'].mean()
per_sample_perax  = df2.groupby(df2.index // 3)['peraxis_pct'].mean()

print('=== Stage 2: Mesh Bounding Box MAPE ===')
print(f'  Isotropic  MAPE: {per_sample_iso.mean():.2f}%  (median {per_sample_iso.median():.2f}%)')
print(f'  Per-axis   MAPE: {per_sample_perax.mean():.2f}%  (median {per_sample_perax.median():.2f}%)')
print(f'  Gap (iso - peraxis): {per_sample_iso.mean() - per_sample_perax.mean():+.2f}pp')

print()
s2 = df2.groupby('rank').agg(
    iso_MAPE=('iso_pct', 'mean'),
    peraxis_MAPE=('peraxis_pct', 'mean'),
).round(2)
s2['gap_pp'] = (s2['iso_MAPE'] - s2['peraxis_MAPE']).round(2)
print(s2.to_string())
# Out:
# === Stage 2: Mesh Bounding Box MAPE ===
#   Isotropic  MAPE: 10.10%  (median 7.07%)
#   Per-axis   MAPE: 5.37%  (median 2.45%)
#   Gap (iso - peraxis): +4.74pp
#
#           iso_MAPE  peraxis_MAPE  gap_pp
# rank
# largest       4.24          4.18    0.06
# middle        9.56          5.80    3.76
# smallest     16.51          6.12   10.39

# %%
# --- Stage 2 scatter: mesh bbox dims vs GT dims (iso and per-axis) ---
rank_order  = ['largest', 'middle', 'smallest']
rank_labels = ['Largest axis', 'Middle axis', 'Smallest axis']

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
fig.suptitle('Stage 2: Scaled mesh bbox dim vs GT dim (rank-matched)', fontsize=13)

for col_idx, (rank, rank_label) in enumerate(zip(rank_order, rank_labels)):
    sub = df2[df2['rank'] == rank]

    for row_idx, (y_col, strategy) in enumerate([('iso', 'Isotropic'), ('peraxis', 'Per-axis')]):
        ax = axes[row_idx][col_idx]
        for cat in sub['category'].unique():
            grp = sub[sub['category'] == cat]
            col = CATEGORY_COLORS.get(cat, 'gray')
            ax.scatter(grp['gt'], grp[y_col], c=col, label=cat, alpha=0.75, s=50, edgecolors='none')
        lo = min(sub['gt'].min(), sub[y_col].min()) * 0.85
        hi = max(sub['gt'].max(), sub[y_col].max()) * 1.15
        ax.plot([lo, hi], [lo, hi], 'k--', lw=1)
        mape = sub[f'{y_col}_pct'].mean()
        ax.set_title(f'{strategy} — {rank_label}\nMAPE = {mape:.2f}%', fontsize=9)
        ax.set_xlabel('GT dim (m)', fontsize=8)
        ax.set_ylabel('Mesh bbox dim (m)', fontsize=8)
        ax.set_xlim(lo, hi); ax.set_ylim(lo, hi)
        ax.set_aspect('equal')
        if col_idx == 2 and row_idx == 0:
            ax.legend(fontsize=7, markerscale=0.9)

plt.tight_layout()
# plt.savefig('artifacts/metric_scale/eval_v3_notebook/stage2_scatter.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 30
#      26         if col_idx == 2 and row_idx == 0:
#      27             ax.legend(fontsize=7, markerscale=0.9)
#      28
#      29 plt.tight_layout()
# ---> 30 plt.savefig('artifacts/metric_scale/eval_v3_notebook/stage2_scatter.png', dpi=150, bbox_inches='tight')
#      31 plt.show()
#
# File /opt/conda/envs/sam3d/lib/python3.11/site-packages/matplotlib/pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# File /opt/conda/envs/sam3d/lib/python3.11/site-packages/matplotlib/figure.py:3497, in Figure.savefig(self, fname, transparent, **kwargs)
#    3495     for ax in self.axes:
#    3496         _recursively_make_axes_transparent(stack, ax)
# -> 3497 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/conda/envs/sam3d/lib/python3.11/site-packages/matplotlib/backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File /opt/conda/envs/sam3d/lib/python3.11/site-packages/matplotlib/backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File /opt/conda/envs/sam3d/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/conda/envs/sam3d/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/conda/envs/sam3d/lib/python3.11/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File /opt/conda/envs/sam3d/lib/python3.11/site-packages/PIL/Image.py:2585, in Image.save(self, fp, format, **params)
#    2583         fp = builtins.open(filename, "r+b")
#    2584     else:
# -> 2585         fp = builtins.open(filename, "w+b")
#    2586 else:
#    2587     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'artifacts/metric_scale/eval_v3_notebook/stage2_scatter.png'

# %%
# --- Gap bar chart: iso vs per-axis MAPE per rank ---
fig, ax = plt.subplots(figsize=(9, 5))

x      = np.arange(3)
width  = 0.35
iso_means   = [df2[df2['rank'] == r]['iso_pct'].mean()    for r in rank_order]
perax_means = [df2[df2['rank'] == r]['peraxis_pct'].mean() for r in rank_order]

b1 = ax.bar(x - width/2, iso_means,   width, label='Isotropic',  color='#d95f02', alpha=0.85)
b2 = ax.bar(x + width/2, perax_means, width, label='Per-axis',   color='#1b9e77', alpha=0.85)

for bar in list(b1) + list(b2):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.2,
            f'{bar.get_height():.1f}%', ha='center', va='bottom', fontsize=9)

ax.set_xticks(x)
ax.set_xticklabels(['Largest axis', 'Middle axis', 'Smallest axis'])
ax.set_ylabel('Mean absolute percentage error (%)')
ax.set_title('Stage 2: Isotropic vs Per-axis mesh MAPE per rank')
ax.legend()
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
# plt.savefig('artifacts/metric_scale/eval_v3_notebook/stage2_gap_bars.png', dpi=150, bbox_inches='tight')
plt.show()

print(f'Aspect ratio gap (overall): {np.mean(iso_means) - np.mean(perax_means):+.2f}pp')
# Out:
# Aspect ratio gap (overall): +4.74pp

# %%
# --- Per-category breakdown (Stage 2) ---
cat_s2 = df2.groupby('category').agg(
    iso_MAPE   =('iso_pct',    'mean'),
    peraxis_MAPE=('peraxis_pct','mean'),
).round(2)
cat_s2['gap_pp'] = (cat_s2['iso_MAPE'] - cat_s2['peraxis_MAPE']).round(2)
cat_s2 = cat_s2.sort_values('gap_pp', ascending=False)
print('=== Stage 2: Per-category mesh MAPE ===')
print(cat_s2.to_string())

# Bar chart
fig, ax = plt.subplots(figsize=(10, 5))
cats = cat_s2.index.tolist()
x2   = np.arange(len(cats))
ax.bar(x2 - width/2, cat_s2['iso_MAPE'],    width, label='Isotropic',  color='#d95f02', alpha=0.85)
ax.bar(x2 + width/2, cat_s2['peraxis_MAPE'],width, label='Per-axis',   color='#1b9e77', alpha=0.85)
ax.set_xticks(x2)
ax.set_xticklabels(cats)
ax.set_ylabel('MAPE (%)')
ax.set_title('Stage 2: Mesh bbox MAPE by category  (iso vs per-axis)')
ax.legend()
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
# plt.savefig('artifacts/metric_scale/eval_v3_notebook/stage2_category_bars.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# === Stage 2: Per-category mesh MAPE ===
#           iso_MAPE  peraxis_MAPE  gap_pp
# category
# laptop       21.41          3.93   17.48
# bottle       14.31          4.77    9.54
# cup           5.39          3.37    2.02
# bowl          7.09          6.01    1.08
# camera        8.02          8.27   -0.25
# can           5.73          6.84   -1.11

# %%
# --- Canonical mesh shape: actual voxel aspect ratio vs GT ---
# Shows how far the SS mesh extents are from the GT proportions (before any scaling)

rows3 = []
for r in results:
    raw_ext    = mesh_bbox_extents(r['verts_canonical'])          # [3]
    raw_sorted = np.sort(raw_ext)[::-1].copy()                    # [3] desc
    gt_sorted  = np.sort(r['gt_dims'])[::-1].copy()               # [3] desc

    # Normalise both to max=1 for shape-only comparison
    raw_norm = raw_sorted / max(raw_sorted[0], 1e-6)
    gt_norm  = gt_sorted  / max(gt_sorted[0],  1e-6)

    for rank, rank_label in enumerate(['largest', 'middle', 'smallest']):
        rows3.append({
            'category': r['category'],
            'rank':     rank_label,
            'gt_norm':  gt_norm[rank],
            'raw_norm': raw_norm[rank],
            'pct_err':  abs(raw_norm[rank] - gt_norm[rank]) / max(gt_norm[rank], 1e-6) * 100,
        })

df3 = pd.DataFrame(rows3)

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Canonical mesh shape vs GT (max-normalised, largest axis = 1.0)', fontsize=12)

for ax, rank in zip(axes, rank_order):
    sub = df3[df3['rank'] == rank]
    for cat in sub['category'].unique():
        grp = sub[sub['category'] == cat]
        col = CATEGORY_COLORS.get(cat, 'gray')
        ax.scatter(grp['gt_norm'], grp['raw_norm'], c=col, label=cat, alpha=0.7, s=50, edgecolors='none')
    ax.plot([0, 1.1], [0, 1.1], 'k--', lw=1)
    ax.set_xlabel('GT normalised extent')
    ax.set_ylabel('Mesh normalised extent')
    mape = sub['pct_err'].mean()
    ax.set_title(f'{rank.capitalize()} axis  |  err = {mape:.1f}%')
    ax.set_xlim(0, 1.15); ax.set_ylim(0, 1.15)
    ax.set_aspect('equal')
    if rank == 'smallest':
        ax.legend(fontsize=7)

plt.tight_layout()
# plt.savefig('artifacts/metric_scale/eval_v3_notebook/canonical_shape.png', dpi=150, bbox_inches='tight')
plt.show()

print('Canonical mesh shape error (before any scaling):')
print(df3.groupby('rank')['pct_err'].mean().round(2).to_string())
# Out:
# Canonical mesh shape error (before any scaling):
# rank
# largest      0.00
# middle       9.05
# smallest    16.85

# %% [markdown]
# ---
# ## Summary

# %%
print('=' * 60)
print(f'CHECKPOINT: {os.path.basename(CHECKPOINT)}')
print(f'Samples:    {len(results)}')
print('=' * 60)

print('\n--- Stage 1: MetricScaleDecoder (pred [W,H,D] vs GT) ---')
for d in ['W', 'H', 'D']:
    mape = df1[df1['dim'] == d]['pct_err'].mean()
    print(f'  {d}: {mape:.2f}%')
print(f'  Overall: {df1["pct_err"].mean():.2f}%')

print('\n--- Stage 2: Mesh bbox (iso vs per-axis) ---')
print(f'  Isotropic MAPE:  {per_sample_iso.mean():.2f}%')
print(f'  Per-axis  MAPE:  {per_sample_perax.mean():.2f}%')
print(f'  Aspect ratio gap: {per_sample_iso.mean() - per_sample_perax.mean():+.2f}pp')

print('\n--- Stage 2 per category ---')
print(cat_s2[['iso_MAPE', 'peraxis_MAPE', 'gap_pp']].to_string())
print('=' * 60)
# Out:
# ============================================================
# CHECKPOINT: nocs_sceneholdout_slat_conditioned_v3_best.pt
# Samples:    64
# ============================================================
#
# --- Stage 1: MetricScaleDecoder (pred [W,H,D] vs GT) ---
#   W: 7.42%
#   H: 4.68%
#   D: 5.23%
#   Overall: 5.78%
#
# --- Stage 2: Mesh bbox (iso vs per-axis) ---
#   Isotropic MAPE:  10.10%
#   Per-axis  MAPE:  5.37%
#   Aspect ratio gap: +4.74pp
#
# --- Stage 2 per category ---
#           iso_MAPE  peraxis_MAPE  gap_pp
# category
# laptop       21.41          3.93   17.48
# bottle       14.31          4.77    9.54
# cup           5.39          3.37    2.02
# bowl          7.09          6.01    1.08
# camera        8.02          8.27   -0.25
# can           5.73          6.84   -1.11
# ============================================================

# %%
# Save all results to JSONL for later analysis
import json
os.makedirs('artifacts/metric_scale/eval_v3_notebook', exist_ok=True)

out_path = 'artifacts/metric_scale/eval_v3_notebook/results.jsonl'
with open(out_path, 'w') as f:
    for r in results:
        row = {
            'category': r['category'],
            'gt_dims':   r['gt_dims'].tolist(),
            'pred_dims': r['pred_dims'].tolist(),
        }
        # Add mesh bbox metrics
        verts     = r['verts_canonical']
        pred_dims = r['pred_dims']
        gt_sorted = np.sort(r['gt_dims'])[::-1].tolist()
        v_iso  = apply_iso_scale(verts, pred_dims)
        v_perax = apply_peraxis_scale(verts, pred_dims)
        row['gt_sorted']     = gt_sorted
        row['bbox_iso']      = np.sort(mesh_bbox_extents(v_iso))[::-1].tolist()
        row['bbox_peraxis']  = np.sort(mesh_bbox_extents(v_perax))[::-1].tolist()
        f.write(json.dumps(row) + '\n')

print(f'Results saved to {out_path}')
# Out:
# Results saved to artifacts/metric_scale/eval_v3_notebook/results.jsonl
