# %% [markdown]
# # Metric Scale Analysis — v3 Heldout Evaluation
#
# Two-stage analysis of metric scale prediction on the 64-sample live heldout set.
#
# **Stage 1**: Direct MetricScaleDecoder output — predicted [W, H, D] vs GT [W, H, D], per-dimension error.
# **Stage 2**: Mesh bounding box accuracy — isotropic scaling (production) vs per-axis rank-matched scaling (upper bound). Quantifies the cost of wrong voxel aspect ratios from SS.

# %%
from __future__ import annotations

import argparse
import json
import os
import sys
import traceback
from pathlib import Path
from typing import Any, Dict, Optional, Tuple

os.environ.setdefault("LIDRA_SKIP_INIT", "1")
os.environ.setdefault("ATTN_BACKEND", "sdpa")
os.environ.setdefault("SPARSE_ATTN_BACKEND", "sdpa")
os.environ.setdefault("CONDA_PREFIX", sys.prefix)

import numpy as np
import torch
from tqdm import tqdm

# utils3d v1.7 compat patches (needed when MoGe's compute_metrics is imported)
import utils3d.torch as _u3t
from utils3d.torch.maps import pixel_coord_map as _pcm, uv_map as _uvm, depth_map_to_point_map as _d2p
from utils3d.torch.utils import sliding_window as _sw
from utils3d.torch.transforms import intrinsics_from_focal_center as _intr_fc
if not hasattr(_u3t, "image_pixel_center"):
    def _image_pixel_center(width, height, dtype=torch.float32, device=None):
        return _pcm(height, width, dtype=dtype, device=device)
    _u3t.image_pixel_center = _image_pixel_center
if not hasattr(_u3t, "image_uv"):
    def _image_uv(width, height, dtype=torch.float32, device=None):
        return _uvm(height, width, dtype=dtype, device=device)
    _u3t.image_uv = _image_uv
if not hasattr(_u3t, "sliding_window_2d"):
    _u3t.sliding_window_2d = _sw
if not hasattr(_u3t, "depth_to_points"):
    def _depth_to_points(depth, intrinsics=None, **kwargs):
        if intrinsics is not None and hasattr(intrinsics, "device") and intrinsics.device != depth.device:
            intrinsics = intrinsics.to(depth.device)
        return _d2p(depth, intrinsics, **kwargs)
    _u3t.depth_to_points = _depth_to_points
if not hasattr(_u3t, "intrinsics_from_focal_center"):
    _u3t.intrinsics_from_focal_center = _intr_fc

from moge.utils.io import read_image, read_depth, read_segmentation

# %%
# ---------------------------------------------------------------------------
# Sample loading (same as eval_metric_depth.py)
# ---------------------------------------------------------------------------

def load_sample(sample_dir: Path):
    rgb = read_image(sample_dir / "image.jpg")                  # (H, W, 3) uint8
    depth, _unit = read_depth(sample_dir / "depth.png")         # (H, W) float, NaN where invalid
    seg, seg_labels = read_segmentation(sample_dir / "segmentation.png")
    K_norm = np.asarray(
        json.loads((sample_dir / "meta.json").read_text())["intrinsics"],
        dtype=np.float32,
    )
    return rgb, depth, seg, seg_labels, K_norm


def backproject_depth_to_points(depth: np.ndarray, K_norm: np.ndarray) -> np.ndarray:
    """(H, W) depth [m] + normalized intrinsics → (H, W, 3) camera-frame points."""
    H, W = depth.shape
    ys, xs = np.meshgrid(np.arange(H), np.arange(W), indexing="ij")
    u_norm = (xs.astype(np.float32) + 0.5) / W
    v_norm = (ys.astype(np.float32) + 0.5) / H
    fx = float(K_norm[0, 0])
    fy = float(K_norm[1, 1])
    cx = float(K_norm[0, 2])
    cy = float(K_norm[1, 2])
    z = depth
    x = (u_norm - cx) / fx * z
    y = (v_norm - cy) / fy * z
    return np.stack([x, y, z], axis=-1).astype(np.float32)


# ---------------------------------------------------------------------------
# 3D bounding box from masked point cloud
# ---------------------------------------------------------------------------

def bbox3d_from_points(points: np.ndarray, mask: np.ndarray) -> Optional[Dict[str, float]]:
    """
    Given [H, W, 3] points and boolean [H, W] mask, return
    axis-aligned 3D bounding box dimensions W/H/D (X/Y/Z range).

    Returns None if fewer than 100 valid masked points.
    NaN/inf values in points are filtered out before computing bbox.
    """
    pts = points[mask]  # [N, 3]
    # Filter out any NaN or inf values (e.g. from MoGe mask boundary, depth holes)
    finite_mask = np.isfinite(pts).all(axis=1)
    pts = pts[finite_mask]
    if len(pts) < 100:
        return None
    mn = pts.min(axis=0)
    mx = pts.max(axis=0)
    dims = (mx - mn).astype(float)
    return {
        "W": float(dims[0]),   # X range
        "H": float(dims[1]),   # Y range
        "D": float(dims[2]),   # Z range (depth)
        "max_whd": float(dims.max()),
        "max_wh": float(dims[:2].max()),
        "n_pts": int(len(pts)),
    }


def bbox_errors(pred: Dict[str, float], gt: Dict[str, float]) -> Dict[str, float]:
    """Compute relative errors and max-dim absolute relative error."""
    out = {}
    for key in ("W", "H", "D", "max_whd", "max_wh"):
        gt_v = gt.get(key, 0.0)
        pred_v = pred.get(key, 0.0)
        if gt_v > 1e-4:
            out[f"rel_{key}"] = abs(pred_v - gt_v) / gt_v
        else:
            out[f"rel_{key}"] = float("nan")
    return out


# ---------------------------------------------------------------------------
# GT bbox from sensor depth
# ---------------------------------------------------------------------------

def gt_bbox(depth: np.ndarray, K_norm: np.ndarray,
            seg_mask: np.ndarray) -> Optional[Dict[str, float]]:
    """Backproject GT depth and compute 3D bbox for the object pixels."""
    valid = np.isfinite(depth) & seg_mask
    if valid.sum() < 100:
        return None
    depth_filled = np.where(valid, depth, 0.0)
    points = backproject_depth_to_points(depth_filled, K_norm)  # [H, W, 3]
    return bbox3d_from_points(points, valid)


# ---------------------------------------------------------------------------
# Estimator adapters
# ---------------------------------------------------------------------------

class MoGe2Estimator:
    """MoGe-2 ViT-L metric point estimator."""

    def __init__(self, device: str = "cuda"):
        # Must use local v2 source since installed moge==1.0.0 only has v1
        import sys as _sys
        if "/mnt/source/MoGe" not in _sys.path:
            _sys.path.insert(0, "/mnt/source/MoGe")
        from moge.model.v2 import MoGeModel
        self.device = device
        print("Loading MoGe-2 ViT-L ...")
        self.model = MoGeModel.from_pretrained("Ruicheng/moge-2-vitl").to(device).eval()
        print("MoGe-2 loaded.")

    @torch.inference_mode()
    def infer_points(self, rgb_hwc_u8: np.ndarray, K_norm: np.ndarray) -> np.ndarray:
        """
        rgb_hwc_u8: (H, W, 3) uint8
        K_norm: (3, 3) normalized intrinsics (not used — MoGe-2 predicts its own)

        Returns: (H, W, 3) metric point map in camera frame [metres].
        NaN where model mask is 0.
        """
        H, W = rgb_hwc_u8.shape[:2]
        img_t = torch.from_numpy(rgb_hwc_u8).permute(2, 0, 1).float().to(self.device) / 255.0
        img_t = img_t.unsqueeze(0)  # [1, 3, H, W]

        out = self.model.infer(img_t, apply_mask=True, force_projection=True)
        # out keys: points [B,H,W,3], depth [B,H,W], intrinsics [B,3,3], mask [B,H,W]
        # apply_mask=True sets out-of-mask points to torch.inf (not NaN)
        pts = out["points"].squeeze(0)  # [H, W, 3] (v2 returns B,H,W,3)
        if pts.ndim == 3 and pts.shape[0] == 3 and pts.shape[-1] != 3:
            pts = pts.permute(1, 2, 0)  # handle [3, H, W] case just in case
        pts_np = pts.cpu().float().numpy()
        # Replace inf (from apply_mask=True) with NaN for downstream handling
        pts_np[~np.isfinite(pts_np)] = np.nan
        return pts_np  # [H, W, 3] metric, NaN outside model mask


class UniDepthV2Estimator:
    """UniDepthV2 ViT-L14 metric depth/point estimator."""

    def __init__(self, device: str = "cuda"):
        import json as _json
        self.device = device
        hub_dir = "/root/.cache/torch/hub/lpiccinelli-eth_UniDepth_main"
        cfg_path = f"{hub_dir}/configs/config_v2_vitl14.json"
        with open(cfg_path) as f:
            config = _json.load(f)
        from unidepth.models import UniDepthV2
        print("Loading UniDepthV2 ViT-L14 ...")
        model = UniDepthV2(config)
        import huggingface_hub
        ckpt_path = huggingface_hub.hf_hub_download(
            repo_id="lpiccinelli/unidepth-v2-vitl14",
            filename="pytorch_model.bin",
        )
        info = model.load_state_dict(torch.load(ckpt_path, map_location="cpu"), strict=False)
        if info.missing_keys:
            print(f"  missing keys: {info.missing_keys[:5]}")
        self.model = model.to(device).eval()
        print("UniDepthV2 loaded.")

    @torch.inference_mode()
    def infer_points(self, rgb_hwc_u8: np.ndarray, K_norm: np.ndarray) -> np.ndarray:
        """
        Returns: (H, W, 3) metric point map in camera frame [metres].
        """
        H, W = rgb_hwc_u8.shape[:2]
        # UniDepthV2.infer expects uint8 [B, 3, H, W] with normalize=True
        img_t = torch.from_numpy(rgb_hwc_u8).permute(2, 0, 1).unsqueeze(0)
        # infer() handles normalization internally
        out = self.model.infer(img_t.float())  # normalize=True does /255 + imagenet norm

        # out["points"] is [B, 3, H, W] metric XYZ
        pts = out["points"].squeeze(0)  # [3, H, W]
        pts = pts.permute(1, 2, 0)     # → [H, W, 3]
        pts_np = pts.cpu().float().numpy()

        # UniDepthV2 gives full-image coverage, no mask needed
        # Depth = Z channel; flag zero-depth as invalid
        depth_valid = pts_np[..., 2] > 0.01
        pts_np[~depth_valid] = np.nan
        return pts_np  # [H, W, 3]

# %% [markdown]
# ## Configuration
# Edit `CHECKPOINT` to switch between checkpoints (v3_best, ss_ratio_v1_best, etc.).

# %%
def _write(f, record):
    def _default(v):
        if isinstance(v, (np.floating, np.integer)): return v.item()
        if hasattr(v, "item"):
            try: return v.item()
            except: pass
        return str(v)
    f.write(json.dumps(record, default=_default) + "\n")
    f.flush()

def load_sample(sample_dir):
    from moge.utils.io import read_image, read_segmentation, read_depth
    # rgb = read_image(sample_dir / "image.jpg")
    rgb = read_image(sample_dir / "image.jpg")                  # (H, W, 3) uint8
    result  = read_depth(sample_dir / "depth.png")         # (H, W) float, NaN where invalid
    depth = result[0] if isinstance(result, tuple) else result
    
    seg, seg_labels = read_segmentation(sample_dir / "segmentation.png")
    K_norm = np.asarray(
        json.loads((sample_dir / "meta.json").read_text())["intrinsics"],
        dtype=np.float32,
    )
    return rgb, depth, seg, seg_labels, K_norm

# %%
# ---------------------------------------------------------------------------
# Per-dataset evaluation loop
# ---------------------------------------------------------------------------

DATASET_FLAGS = {
    "HAMMER":  {},
    "iBims-1": {},
    "DIODE":   {},
}


def run_dataset(
    estimator,
    estimator_name: str,
    dataset_name: str,
    dataset_root: Path,
    out_f,
    limit: Optional[int],
    seed: int,
):
    rng = np.random.default_rng(seed)
    index = [s for s in (dataset_root / ".index.txt").read_text().splitlines() if s.strip()]
    if limit is not None:
        idx = rng.choice(len(index), min(limit, len(index)), replace=False)
        idx.sort()
        index = [index[i] for i in idx]

    n_ok, n_fail = 0, 0
    for sample_id in tqdm(index, desc=f"{estimator_name}/{dataset_name}"):
        sample_dir = dataset_root / sample_id
        try:
            rgb, depth, seg, seg_labels, K_norm = load_sample(sample_dir)
            print("seg_label:", seg_labels) 
            import matplotlib.pyplot as plt

            fig, axes = plt.subplots(1, 3, figsize=(15,5))
            axes[0].imshow(rgb)
            axes[0].set_title("RGB")
            axes[0].axis("off")

            im = axes[1].imshow(depth,cmap="plasma")
            axes[1].set_title("Depth (m)")
            axes[1].axis("off")
            # plt.colorbar(im, ax=axes[1])

            # Overlay the seg mask on the RGB image to see the selected instance we are working on
            axes[2].imshow(rgb)
            axes[2].imshow(seg == 1, alpha=0.5, cmap="Reds")
            axes[2].set_title("Object mask (red = label 1)")
            axes[2].axis("off")

            plt.tight_layout()
            plt.show()
        except Exception as e:
            n_fail += 1
            _write(out_f, {
                "estimator": estimator_name,
                "dataset": dataset_name,
                "sample_id": sample_id,
                "error": f"load_sample: {e}",
            })
            continue

        # Object mask — label==1 (as set by our converters)
        seg_mask = (seg == 1)
        if seg_mask.sum() < 100:
            # Skip samples with no usable object pixels
            continue

        # GT 3D bbox from sensor depth
        gt_box = gt_bbox(depth, K_norm, seg_mask)
        if gt_box is None:
            continue

        # Predicted point map
        try:
            with torch.inference_mode():
                if isinstance(estimator, Sam3DEstimator):
                    pts_pred = estimator.infer_points(rgb, K_norm, seg_mask)
                else:
                    pts_pred = estimator.infer_points(rgb, K_norm)
        except Exception:
            n_fail += 1
            _write(out_f, {
                "estimator": estimator_name,
                "dataset": dataset_name,
                "sample_id": sample_id,
                "error": traceback.format_exc().splitlines()[-1],
            })
            torch.cuda.empty_cache()
            continue

        # Pred bbox — use same visible pixels where GT depth is valid
        # (fair comparison: both measure what the sensor saw)
        gt_valid_mask = np.isfinite(depth) & seg_mask
        pred_box_visible = bbox3d_from_points(pts_pred, gt_valid_mask)

        # Also measure pred bbox over all object mask pixels (model's full view)
        # bbox3d_from_points handles NaN/inf filtering internally
        pred_box_full = bbox3d_from_points(pts_pred, seg_mask)

        record = {
            "estimator": estimator_name,
            "dataset": dataset_name,
            "sample_id": sample_id,
            "gt_bbox": gt_box,
        }
        if pred_box_visible is not None:
            record["pred_bbox_visible"] = pred_box_visible
            record["errors_visible"] = bbox_errors(pred_box_visible, gt_box)
        if pred_box_full is not None:
            record["pred_bbox_full"] = pred_box_full
            record["errors_full"] = bbox_errors(pred_box_full, gt_box)
        _write(out_f, record)
        n_ok += 1

    print(f"[{estimator_name}/{dataset_name}] {n_ok} ok, {n_fail} fail")

# %%
file = "/mnt/source/datasets_sam3d/eval/HAMMER/scene2_traj2_2_f000100_obj200/"
d = os.path.join(file,"depth.png")
rgb = os.path.join(file,"image.jpg")
seg = os.path.join(file,"segmentation.png")

# %%
plt.imshow(d)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 plt.imshow(d)
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
limit = 3
with output.open(mode) as f:
    for ds in ["HAMMER"]:
        run_dataset(
            estimator, "moge2", ds,
            dataset_root=Path("/mnt/source/datasets_sam3d/eval") / ds,
            out_f=f,
            limit=limit,
            seed=seed,
        )
# Out:
# moge2/HAMMER:   0%|                                                                                                                                   | 0/3 [00:00<?, ?it/s]
# seg_label: {'object': 1}
# moge2/HAMMER:  33%|█████████████████████████████████████████                                                                                  | 1/3 [00:00<00:01,  1.27it/s]
# seg_label: {'object': 1}
# moge2/HAMMER:  67%|██████████████████████████████████████████████████████████████████████████████████                                         | 2/3 [00:01<00:00,  1.23it/s]
# seg_label: {'object': 1}
# moge2/HAMMER: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:02<00:00,  1.14it/s]
# [moge2/HAMMER] 0 ok, 3 fail

# %%
# ap = argparse.ArgumentParser(description=__doc__)
# ap.add_argument("--estimator", required=True,
#                 choices=["moge2", "unidepth2", "sam3d"])
# ap.add_argument("--datasets", nargs="+", default=["HAMMER", "iBims-1"])
# ap.add_argument("--datasets-root", type=Path,
#                 default=Path("/mnt/source/datasets_sam3d/eval"))
# ap.add_argument("--output", type=Path, required=True)
# ap.add_argument("--append", action="store_true")
# ap.add_argument("--device", default="cuda")
# ap.add_argument("--limit", type=int, default=None)
# ap.add_argument("--seed", type=int, default=42)
# # sam3d-specific
# ap.add_argument("--config", type=Path)
# ap.add_argument("--metric-checkpoint", type=Path)
# args = ap.parse_args()

# Build estimator
# if args.estimator == "moge2":
estimator = MoGe2Estimator(device="cuda")
# elif args.estimator == "unidepth2":
#     estimator = UniDepthV2Estimator(device=args.device)
# elif args.estimator == "sam3d":
#     if not args.config or not args.metric_checkpoint:
#         ap.error("--estimator sam3d requires --config and --metric-checkpoint")
#     estimator = Sam3DEstimator(
#         config=str(args.config),
#         metric_checkpoint=str(args.metric_checkpoint),
#         device=args.device,
#         seed=args.seed,
#     )
# else:
#     raise NotImplementedError(args.estimator)

# args.output.parent.mkdir(parents=True, exist_ok=True)
mode = "a" #if args.append else "w"
seed = 42
limit = 1
output = Path("artifacts/eval_bbox/sam3d_v3_bbox.jsonl")
output.parent.mkdir(parents=True, exist_ok=True)

with output.open(mode) as f:
    for ds in ["HAMMER"]:
        run_dataset(
            estimator, "moge2", ds,
            dataset_root=Path("/mnt/source/datasets_sam3d/eval") / ds,
            out_f=f,
            limit=limit,
            seed=seed,
        )
# Out:
# Loading MoGe-2 ViT-L ...
# MoGe-2 loaded.
# moge2/HAMMER:   0%|                                                                                                                                   | 0/1 [00:00<?, ?it/s]
# moge2/HAMMER: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.10it/s]
# [moge2/HAMMER] 0 ok, 1 fail

# %% [markdown]
# ## Load Pipeline, Heads, Dataset

# %%
from hydra.utils import instantiate
from omegaconf import OmegaConf

print('Loading pipeline...')
config = OmegaConf.load(CONFIG)
config.workspace_dir = os.path.dirname(CONFIG)
config.compile_model = False
config.device = DEVICE
pipeline = instantiate(config)
freeze_pipeline(pipeline)
print('Pipeline loaded.')

scale_head    = MetricScaleHead().to(DEVICE).eval()
scale_decoder = MetricScaleDecoder().to(DEVICE).eval()
load_metric_checkpoint(CHECKPOINT, scale_head, scale_decoder)
print(f'Checkpoint loaded: {CHECKPOINT}')
# Out:
# Loading pipeline...
# 2026-05-21 20:16:38.069 | INFO     | sam3d_objects.pipeline.inference_pipeline:set_attention_backend:17 - GPU name is NVIDIA A10
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# 2026-05-21 20:16:43.421 | INFO     | sam3d_objects.model.backbone.tdfy_dit.modules.sparse:__from_env:39 - [SPARSE] Backend: spconv, Attention: sdpa
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:51: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   _TORCH_CUSTOM_FWD = amp.custom_fwd(cast_inputs=torch.float16)
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:100: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:166: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:246: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:335: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:372: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:392: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/spconv/pytorch/functional.py:415: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @_TORCH_CUSTOM_BWD
# 2026-05-21 20:16:48.782 | INFO     | sam3d_objects.model.backbone.tdfy_dit.modules.attention:__from_env:30 - [ATTENTION] Using backend: sdpa
# [SPARSE][CONV] spconv algo: auto
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/lightning/fabric/__init__.py:41: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# 2026-05-21 20:16:52.306 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# 2026-05-21 20:16:52.306 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# 2026-05-21 20:16:52.461 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# model.pt:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# /opt/conda/envs/sam3d/lib/python3.11/site-packages/moge/model/v1.py:171: UserWarning: The following deprecated/invalid arguments are ignored: {'output_mask': True, 'split_head': True}
#   warnings.warn(f"The following deprecated/invalid arguments are ignored: {deprecated_kwargs}")
# 2026-05-21 20:17:06.460 | WARNING  | sam3d_objects.data.dataset.tdfy.preprocessor:__post_init__:51 - No rgb pointmap normalizer provided, using scale + shift
# 2026-05-21 20:17:06.462 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:102 - self.device: cuda
# 2026-05-21 20:17:06.462 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:103 - CUDA_VISIBLE_DEVICES: None
# 2026-05-21 20:17:06.463 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:104 - Actually using GPU: 0
# 2026-05-21 20:17:06.463 | INFO     | sam3d_objects.pipeline.inference_pipeline:init_pose_decoder:299 - Using pose decoder: ScaleShiftInvariant
# 2026-05-21 20:17:06.463 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:135 - Loading model weights...
# 2026-05-21 20:17:09.781 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/ss_generator.ckpt
# 2026-05-21 20:19:09.741 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/slat_generator.ckpt
# 2026-05-21 20:20:31.208 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/ss_decoder.ckpt
# 2026-05-21 20:20:34.653 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/slat_decoder_gs.ckpt
# 2026-05-21 20:20:38.775 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/slat_decoder_gs_4.ckpt
# 2026-05-21 20:20:42.442 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/slat_decoder_mesh.ckpt
# 2026-05-21 20:20:45.116 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vitl14/dinov2_vitl14_reg4_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vitl14_reg4_pretrain.pth
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1.13G/1.13G [00:03<00:00, 355MB/s]
# 2026-05-21 20:20:52.157 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-05-21 20:20:52.163 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-05-21 20:20:52.839 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-05-21 20:20:52.862 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/ss_generator.ckpt
# 2026-05-21 20:20:55.720 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-05-21 20:20:56.432 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-05-21 20:20:56.438 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:31 - Loading DINO model: dinov2_vitl14_reg from facebookresearch/dinov2 (source: github)
# 2026-05-21 20:20:57.734 | INFO     | sam3d_objects.model.backbone.dit.embedder.dino:__init__:44 - Loaded DINO model - type: <class 'dinov2.models.vision_transformer.DinoVisionTransformer'>, embed_dim: 1024, patch_size: (14, 14)
# 2026-05-21 20:20:57.743 | INFO     | sam3d_objects.model.io:load_model_from_checkpoint:158 - Loading checkpoint from checkpoints/hf/slat_generator.ckpt
# 2026-05-21 20:20:59.555 | INFO     | sam3d_objects.pipeline.inference_pipeline:override_ss_generator_cfg_config:440 - ss_generator parameters: inference_steps=25, cfg_strength=7, cfg_interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:20:59.556 | INFO     | sam3d_objects.pipeline.inference_pipeline:override_slat_generator_cfg_config:462 - slat_generator parameters: inference_steps=25, cfg_strength=1, cfg_interval=[0, 500], rescale_t=1
# 2026-05-21 20:20:59.557 | INFO     | sam3d_objects.pipeline.inference_pipeline:__init__:200 - Loading model weights completed!
# Pipeline loaded.
# Loaded metric scale checkpoint from artifacts/metric_scale/checkpoints/nocs_sceneholdout_ss_ratio_v1_best.pt
# Checkpoint loaded: artifacts/metric_scale/checkpoints/nocs_sceneholdout_ss_ratio_v1_best.pt

# %%
# Replicate the training heldout split:
# --split-group record --heldout-samples 64 --seed 0 (no --shuffle-split)
# => heldout = last 64 records in dataset order

full_dataset = OmniNOCSReal275Dataset(
    annotations_root=ANNOTATIONS,
    rgb_root=RGB_ROOT,
    split='train',
    min_mask_pixels=500,
)
n = len(full_dataset)
heldout_indices = list(range(n - HELDOUT_N, n))
heldout_dataset = Subset(full_dataset, heldout_indices)
print(f'Full dataset: {n}  |  Heldout: {len(heldout_dataset)} samples')
# Out:
# Full dataset: 16118  |  Heldout: 64 samples

# %% [markdown]
# ## Run Inference on All 64 Heldout Samples
#
# Collects per-sample:
# - `pred_dims`: raw MetricScaleDecoder output [W, H, D] in metres
# - `gt_dims`: ground-truth [W, H, D] in metres
# - `verts_canonical`: mesh vertices in unit-cube canonical space
# - `faces`: triangle indices

# %%
import torch.nn.functional as F

def run_sample(item):
    """Returns a results dict for one heldout sample."""
    image   = item['image']             # np [H,W,4] uint8
    gt_dims = np.array(item['metric_dims'], dtype=np.float32)  # [W, H, D]
    category = item.get('category', 'unknown')

    with torch.no_grad():
        # --- Depth / conditioning ---
        pointmap_dict   = pipeline.compute_pointmap(image)
        ss_input_dict   = pipeline.preprocess_image(
            image, pipeline.ss_preprocessor,
            pointmap=pointmap_dict['pointmap'])
        slat_input_dict = pipeline.preprocess_image(image, pipeline.slat_preprocessor)

        # --- Stage 1: SS ---
        ss_ret = pipeline.sample_sparse_structure(
            ss_input_dict, inference_steps=STAGE1_STEPS, use_distillation=False)

        # --- Metric scale token ---
        ss_feats = extract_ss_scale_features(ss_ret)
        if ss_feats is not None:
            ss_feats = ss_feats.to(DEVICE)
        scale_token = scale_head(
            ss_ret['shape'],
            ss_feats,
            ss_input_dict.get('pointmap_scale'),
            ss_input_dict.get('pointmap_shift'),
        )

        # --- Inject into SLAT conditioning ---
        token_norm   = F.layer_norm(scale_token, [scale_token.shape[-1]])
        slat_backbone = pipeline._get_slat_backbone()
        orig_bb_emb  = orig_ext_emb = None
        if slat_backbone is not None:
            orig_bb_emb = slat_backbone.condition_embedder
            slat_backbone.condition_embedder = _ScaleAugmentedEmbedderProxy(orig_bb_emb, token_norm)
        cond_embs = getattr(pipeline, 'condition_embedders', {})
        orig_ext_emb = cond_embs.get('slat_condition_embedder')
        if orig_ext_emb is not None:
            pipeline.condition_embedders['slat_condition_embedder'] = \
                _ScaleAugmentedEmbedderProxy(orig_ext_emb, token_norm)

        try:
            slat = pipeline.sample_slat(
                slat_input_dict, ss_ret['coords'],
                inference_steps=STAGE2_STEPS, use_distillation=False)
        finally:
            if orig_bb_emb is not None and slat_backbone is not None:
                slat_backbone.condition_embedder = orig_bb_emb
            if orig_ext_emb is not None:
                pipeline.condition_embedders['slat_condition_embedder'] = orig_ext_emb

        # --- Decode mesh ---
        decoded    = pipeline.decode_slat(slat, formats=['mesh'])
        mesh       = decoded['mesh'][0]

        # --- Metric prediction [W, H, D] ---
        log_dims   = scale_decoder(slat.feats, scale_token, slat.coords[:, 0])
        pred_dims  = torch.exp(log_dims[0]).cpu().numpy()  # [3] W,H,D

    verts = mesh.vertices.float().cpu().numpy()  # [N, 3]
    faces = mesh.faces.int().cpu().numpy()        # [F, 3]

    return {
        'category':       category,
        'gt_dims':        gt_dims,          # [W, H, D] metres
        'pred_dims':      pred_dims,        # [W, H, D] metres
        'verts_canonical': verts,
        'faces':           faces,
    }

print('run_sample defined')
# Out:
# run_sample defined

# %%
results = []
skipped = 0

for i in tqdm(range(len(heldout_dataset)), desc='Running inference'):
    item = heldout_dataset[i]
    try:
        r = run_sample(item)
        results.append(r)
    except Exception as e:
        print(f'  [skip {i}] {e}')
        skipped += 1

print(f'\nDone. {len(results)} samples collected, {skipped} skipped.')
# Out:
# Running inference:   0%|          | 0/64 [00:00<?, ?it/s]
# 2026-05-21 20:21:12.552 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:21:12.553 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:12.695 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:14.499 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 15068 to 13234
# 2026-05-21 20:21:14.506 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:21:14.507 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:14.585 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:17.517 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:21:35.890 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:21:35.894 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:36.025 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:37.812 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 13127 to 13125
# 2026-05-21 20:21:37.813 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:21:37.814 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:37.883 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:38.331 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:21:39.338 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:21:39.341 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:39.470 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:41.257 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 33041 to 24763
# 2026-05-21 20:21:41.259 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:21:41.259 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:41.331 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:42.287 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:21:44.094 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:21:44.096 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:44.226 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:46.016 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 18433 to 16603
# 2026-05-21 20:21:46.018 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:21:46.018 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:46.093 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:46.628 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:21:48.159 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:21:48.162 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:48.292 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:50.082 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 67723 to 11538
# 2026-05-21 20:21:50.084 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:21:50.084 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:50.160 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:50.501 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:21:51.328 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:21:51.329 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:51.457 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:53.245 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 10373 to 10372
# 2026-05-21 20:21:53.247 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:21:53.247 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:53.325 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:53.656 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:21:54.373 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:21:54.375 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:54.504 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:56.292 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 23696 to 23602
# 2026-05-21 20:21:56.294 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:21:56.294 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:56.364 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:21:57.179 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:21:59.038 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:21:59.042 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:21:59.173 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:00.964 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 19487 to 17024
# 2026-05-21 20:22:00.966 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:00.966 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:01.038 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:01.570 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:02.543 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:02.545 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:02.674 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:04.466 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 17942 to 14686
# 2026-05-21 20:22:04.467 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:04.468 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:04.537 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:05.055 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:06.186 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:06.188 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:06.321 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:08.111 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 28074 to 27648
# 2026-05-21 20:22:08.112 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:08.113 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:08.183 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:09.163 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:11.194 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:11.198 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:11.328 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:13.121 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 13379 to 12387
# 2026-05-21 20:22:13.122 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:13.123 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:13.191 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:13.600 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:14.348 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:14.350 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:14.479 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:16.274 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 26413 to 24387
# 2026-05-21 20:22:16.275 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:16.275 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:16.350 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:17.162 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:19.139 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:19.141 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:19.271 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:21.068 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 12206 to 12200
# 2026-05-21 20:22:21.069 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:21.070 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:21.144 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:21.555 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:22.264 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:22.266 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:22.395 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:24.193 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 22365 to 17468
# 2026-05-21 20:22:24.195 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:24.195 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:24.263 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:24.884 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:26.006 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:26.008 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:26.138 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:27.934 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 29022 to 25284
# 2026-05-21 20:22:27.936 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:27.936 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:28.011 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:28.878 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:31.357 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:31.360 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:31.490 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:33.288 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 11084 to 11084
# 2026-05-21 20:22:33.289 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:33.290 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:33.359 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:33.713 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:34.369 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:34.371 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:34.501 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:36.304 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 33136 to 30451
# 2026-05-21 20:22:36.305 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:36.306 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:36.378 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:37.501 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:40.631 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:40.633 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:40.763 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:42.566 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 43151 to 31455
# 2026-05-21 20:22:42.568 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:42.568 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:42.642 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:43.974 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:46.980 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:46.982 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:47.116 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:48.922 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 23629 to 22949
# 2026-05-21 20:22:48.924 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:48.924 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:48.998 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:49.722 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:51.508 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:51.510 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:51.640 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:53.446 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 18617 to 18557
# 2026-05-21 20:22:53.448 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:53.448 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:53.519 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:54.152 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:55.292 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:55.294 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:55.424 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:57.228 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 22313 to 18822
# 2026-05-21 20:22:57.230 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:22:57.230 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:57.299 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:22:57.906 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:22:59.527 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:22:59.530 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:22:59.660 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:01.465 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 33150 to 28618
# 2026-05-21 20:23:01.466 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:01.467 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:01.534 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:02.622 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:05.178 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:05.181 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:05.313 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:07.121 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 14779 to 14747
# 2026-05-21 20:23:07.123 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:07.123 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:07.194 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:07.679 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:08.582 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:08.584 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:08.714 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:10.521 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 19576 to 14306
# 2026-05-21 20:23:10.522 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:10.523 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:10.597 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:11.110 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:11.999 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:12.001 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:12.131 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:13.939 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 18279 to 17888
# 2026-05-21 20:23:13.941 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:13.942 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:14.010 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:14.548 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:15.653 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:15.655 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:15.786 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:17.595 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 18806 to 18791
# 2026-05-21 20:23:17.596 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:17.596 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:17.667 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:18.369 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:19.681 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:19.683 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:19.813 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:21.623 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 17591 to 15513
# 2026-05-21 20:23:21.624 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:21.625 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:21.692 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:22.214 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:23.457 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:23.459 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:23.589 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:25.398 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 10486 to 10459
# 2026-05-21 20:23:25.399 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:25.399 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:25.468 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:25.814 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:26.431 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:26.433 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:26.564 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:28.373 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 26111 to 23964
# 2026-05-21 20:23:28.374 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:28.374 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:28.447 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:29.294 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:31.024 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:31.026 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:31.156 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:32.968 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 31950 to 30523
# 2026-05-21 20:23:32.969 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:32.970 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:33.048 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:34.062 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:36.452 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:36.453 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:36.583 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:38.395 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 13571 to 13436
# 2026-05-21 20:23:38.397 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:38.397 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:38.465 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:38.959 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:39.951 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:39.952 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:40.082 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:41.894 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 35728 to 32034
# 2026-05-21 20:23:41.895 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:41.895 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:41.966 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:43.134 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:46.745 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:46.747 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:46.877 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:48.688 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 19115 to 17054
# 2026-05-21 20:23:48.689 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:48.689 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:48.763 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:49.314 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:51.092 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:51.093 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:51.223 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:53.034 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 10505 to 10053
# 2026-05-21 20:23:53.035 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:53.035 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:53.106 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:53.461 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:54.135 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:54.139 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:54.270 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:56.083 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 16237 to 12980
# 2026-05-21 20:23:56.084 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:56.084 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:56.157 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:56.617 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:23:57.406 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:23:57.408 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:57.539 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:23:59.348 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 27925 to 21532
# 2026-05-21 20:23:59.350 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:23:59.350 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:23:59.418 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:24:00.178 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:24:01.655 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:24:01.657 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:24:01.787 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:24:03.582 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 15777 to 15750
# 2026-05-21 20:24:03.583 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:24:03.583 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:24:03.654 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:24:04.137 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:24:05.149 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:24:05.151 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:24:05.280 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:24:07.075 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 15735 to 15656
# 2026-05-21 20:24:07.076 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:24:07.077 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:24:07.151 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:24:07.647 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:24:08.621 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:24:08.623 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:24:08.754 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:24:10.546 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 33588 to 31557
# 2026-05-21 20:24:10.547 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:24:10.548 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:24:10.621 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:24:11.692 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:24:14.819 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:24:14.821 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:24:14.950 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# ...
# 2026-05-21 20:25:04.511 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:05.879 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:05.882 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:06.011 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:07.804 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 27263 to 22591
# 2026-05-21 20:25:07.805 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:25:07.806 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:07.876 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:08.754 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:10.643 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:10.646 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:10.775 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:12.568 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 18018 to 15898
# 2026-05-21 20:25:12.569 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:25:12.569 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:12.639 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:13.232 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:14.431 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:14.434 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:14.563 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:16.356 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 17217 to 16318
# 2026-05-21 20:25:16.357 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:25:16.358 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:16.430 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:16.950 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:17.911 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:17.913 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:18.042 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:19.836 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 15181 to 15130
# 2026-05-21 20:25:19.838 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:25:19.838 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:19.912 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:20.346 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:21.255 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:21.257 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:21.386 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:23.182 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 29136 to 22367
# 2026-05-21 20:25:23.183 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:25:23.183 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:23.251 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:24.107 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:25.678 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:25.680 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:25.810 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:27.604 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 17705 to 16459
# 2026-05-21 20:25:27.605 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:25:27.605 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:27.678 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:28.191 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:29.239 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:29.241 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:29.371 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:31.163 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 25928 to 25095
# 2026-05-21 20:25:31.164 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:25:31.164 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:31.235 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:32.196 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:34.526 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:34.529 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:34.659 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:36.452 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 12990 to 12990
# 2026-05-21 20:25:36.453 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:25:36.453 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:36.525 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:36.941 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:37.901 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:37.902 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:38.032 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:39.827 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 22626 to 20107
# 2026-05-21 20:25:39.828 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:25:39.829 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:39.899 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:40.596 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:42.145 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:42.148 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:42.281 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:44.072 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 19815 to 18075
# 2026-05-21 20:25:44.073 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:25:44.073 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:44.146 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:44.768 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:46.176 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:46.178 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:46.307 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:48.103 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 49547 to 39120
# 2026-05-21 20:25:48.104 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:25:48.105 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:48.173 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:49.752 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:54.319 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:54.321 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:54.451 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:56.246 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 19682 to 19400
# 2026-05-21 20:25:56.247 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:25:56.248 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:56.317 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:25:56.945 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# 2026-05-21 20:25:58.257 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:668 - Sampling sparse structure: inference_steps=4, strength=7, interval=[0, 500], rescale_t=3, cfg_strength_pm=0.0
# 2026-05-21 20:25:58.259 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:25:58.389 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:26:00.185 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_sparse_structure:718 - Downsampled coords from 17283 to 13486
# 2026-05-21 20:26:00.186 | INFO     | sam3d_objects.pipeline.inference_pipeline:sample_slat:749 - Sampling sparse latent: inference_steps=1, strength=1, interval=[0, 500], rescale_t=1
# 2026-05-21 20:26:00.187 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:637 - Running condition embedder ...
# 2026-05-21 20:26:00.260 | INFO     | sam3d_objects.pipeline.inference_pipeline:get_condition_input:641 - Condition embedder finishes!
# 2026-05-21 20:26:00.739 | INFO     | sam3d_objects.pipeline.inference_pipeline:decode_slat:610 - Decoding sparse latent...
# Done. 64 samples collected, 0 skipped.

# %% [markdown]
# ---
# ## Stage 1 — MetricScaleDecoder: Predicted vs GT [W, H, D]
#
# The decoder outputs three values corresponding directly to GT W (width), H (height), D (depth) in metres.

# %%
# Build a flat DataFrame for Stage 1
rows = []
for r in results:
    for dim_idx, dim_name in enumerate(['W', 'H', 'D']):
        rows.append({
            'category':  r['category'],
            'dim':       dim_name,
            'gt':        r['gt_dims'][dim_idx],
            'pred':      r['pred_dims'][dim_idx],
            'abs_err':   abs(r['pred_dims'][dim_idx] - r['gt_dims'][dim_idx]),
            'pct_err':   abs(r['pred_dims'][dim_idx] - r['gt_dims'][dim_idx]) /
                         max(r['gt_dims'][dim_idx], 1e-6) * 100,
        })
df1 = pd.DataFrame(rows)

# Summary table
summary1 = df1.groupby('dim').agg(
    MAPE=('pct_err', 'mean'),
    Median_APE=('pct_err', 'median'),
    Mean_abs_cm=('abs_err', lambda x: x.mean() * 100),
).round(3)
print('=== Stage 1: Per-dimension prediction error ===')
print(summary1.to_string())

overall_mape = df1['pct_err'].mean()
print(f'\nOverall MAPE across W,H,D: {overall_mape:.3f}%')
# Out:
# === Stage 1: Per-dimension prediction error ===
#           MAPE  Median_APE  Mean_abs_cm
# dim
# D    19.389000      12.712        2.175
# H    42.946999      13.231        3.879
# W    52.540001      13.627        4.638
#
# Overall MAPE across W,H,D: 38.292%

# %%
# --- Scatter: Predicted vs GT per dimension ---
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Stage 1: MetricScaleDecoder  —  Predicted vs GT dimension (metres)', fontsize=13)

for ax, dim_name in zip(axes, ['W', 'H', 'D']):
    sub = df1[df1['dim'] == dim_name]
    for cat, grp in sub.groupby('category'):
        col = CATEGORY_COLORS.get(cat, 'gray')
        ax.scatter(grp['gt'], grp['pred'], c=col, label=cat, alpha=0.75, s=50, edgecolors='none')
    lo = min(sub['gt'].min(), sub['pred'].min()) * 0.9
    hi = max(sub['gt'].max(), sub['pred'].max()) * 1.1
    ax.plot([lo, hi], [lo, hi], 'k--', lw=1, label='perfect')
    ax.set_xlabel(f'GT {dim_name} (m)')
    ax.set_ylabel(f'Pred {dim_name} (m)')
    mape = sub['pct_err'].mean()
    ax.set_title(f'{dim_name}  |  MAPE = {mape:.2f}%')
    ax.legend(fontsize=7, markerscale=0.9)
    ax.set_xlim(lo, hi)
    ax.set_ylim(lo, hi)
    ax.set_aspect('equal')

plt.tight_layout()
#plt.savefig('/mnt/source/sam-3d-objects/artifacts/metric_scale/eval_v3_notebook/stage1_scatter.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# --- Per-category MAPE breakdown (Stage 1) ---
cat_dim = df1.groupby(['category', 'dim'])['pct_err'].mean().unstack('dim').round(2)
cat_dim['mean'] = cat_dim.mean(axis=1).round(2)
print('=== Stage 1: Per-category MAPE (%) per dimension ===')
print(cat_dim.to_string())
# Out:
# === Stage 1: Per-category MAPE (%) per dimension ===
# dim               D          H           W       mean
# category
# bottle    14.360000  47.889999   49.599998  37.279999
# bowl      13.410000   7.180000    5.920000   8.840000
# camera    52.349998  66.500000  147.889999  88.910004
# can       12.630000  90.089996   95.330002  66.019997
# cup       28.299999  52.860001   44.619999  41.930000
# laptop     2.290000   1.930000    3.020000   2.410000

# %%
# --- Error distribution violin plots (Stage 1) ---
import matplotlib.ticker as ticker

fig, ax = plt.subplots(figsize=(9, 5))
dim_order = ['W', 'H', 'D']
data_by_dim = [df1[df1['dim'] == d]['pct_err'].values for d in dim_order]

parts = ax.violinplot(data_by_dim, positions=[1, 2, 3], showmedians=True, showextrema=True)
for pc in parts['bodies']:
    pc.set_facecolor('#4682b4')
    pc.set_alpha(0.6)

ax.set_xticks([1, 2, 3])
ax.set_xticklabels(['Width (W)', 'Height (H)', 'Depth (D)'])
ax.set_ylabel('Absolute percentage error (%)')
ax.set_title('Stage 1: Prediction error distribution per dimension')
ax.yaxis.set_minor_locator(ticker.AutoMinorLocator())
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
#plt.savefig('artifacts/metric_scale/eval_v3_notebook/stage1_violin.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# --- Aspect ratio accuracy: predicted ratio vs GT ratio ---
# Visualise how well the decoder captures the shape proportions (W:H, W:D)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle('Stage 1: Predicted aspect ratio vs GT aspect ratio')

for ax, (num_dim, den_dim) in zip(axes, [(0, 1), (0, 2)]):
    num_lbl = ['W', 'H', 'D'][num_dim]
    den_lbl = ['W', 'H', 'D'][den_dim]
    for r in results:
        cat = r['category']
        col = CATEGORY_COLORS.get(cat, 'gray')
        gt_ratio   = r['gt_dims'][num_dim]   / max(r['gt_dims'][den_dim],   1e-6)
        pred_ratio = r['pred_dims'][num_dim] / max(r['pred_dims'][den_dim], 1e-6)
        ax.scatter(gt_ratio, pred_ratio, c=col, alpha=0.7, s=50, edgecolors='none')
    lo = 0
    hi = max(ax.get_xlim()[1], ax.get_ylim()[1]) * 1.1
    ax.plot([lo, hi], [lo, hi], 'k--', lw=1)
    ax.set_xlabel(f'GT  {num_lbl}/{den_lbl}')
    ax.set_ylabel(f'Pred {num_lbl}/{den_lbl}')
    ax.set_title(f'{num_lbl} / {den_lbl} aspect ratio')

# Legend
patches = [mpatches.Patch(color=c, label=k) for k, c in CATEGORY_COLORS.items()]
axes[-1].legend(handles=patches, fontsize=8)
plt.tight_layout()
# plt.savefig('artifacts/metric_scale/eval_v3_notebook/stage1_aspect_ratio.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## Stage 2 — Mesh Bounding Box: Isotropic vs Per-Axis Scaling
#
# The canonical mesh has `max(bbox) ≈ 1.0` by construction (FlexiCubes).
# Two scaling strategies bring it into metric space:
#
# - **Isotropic** (production): `s = max(W_pred, H_pred, D_pred)` — all vertices × s
# - **Per-axis** (upper bound): rank-sort predicted dims descending, rank-sort mesh extents descending, scale each axis so its extent = corresponding predicted dim
#
# Both results are rank-sorted for comparison against GT (largest mesh extent ↔ largest GT dim).

# %%
def mesh_bbox_extents(verts):
    return verts.max(axis=0) - verts.min(axis=0)  # [3]

def apply_iso_scale(verts, pred_dims):
    s = pred_dims.max()
    return verts * s

def apply_peraxis_scale(verts, pred_dims):
    raw_ext  = mesh_bbox_extents(verts)          # [3] per-axis extents
    pred_sorted = np.sort(pred_dims)[::-1].copy() # [3] desc
    ext_rank    = np.argsort(raw_ext)[::-1]       # axis indices sorted by extent desc
    scale_factors = np.ones(3, dtype=np.float64)
    center = (verts.min(axis=0) + verts.max(axis=0)) / 2.0
    for rank, axis in enumerate(ext_rank):
        if raw_ext[axis] > 1e-6:
            scale_factors[axis] = pred_sorted[rank] / raw_ext[axis]
        else:
            scale_factors[axis] = 1.0
    return center + (verts - center) * scale_factors

# Compute Stage 2 metrics for all results
rows2 = []
for r in results:
    verts     = r['verts_canonical']
    pred_dims = r['pred_dims']
    gt_sorted = np.sort(r['gt_dims'])[::-1].copy()    # [3] desc

    # Isotropic
    v_iso   = apply_iso_scale(verts, pred_dims)
    ext_iso = np.sort(mesh_bbox_extents(v_iso))[::-1]  # [3] desc

    # Per-axis
    v_perax   = apply_peraxis_scale(verts, pred_dims)
    ext_perax = np.sort(mesh_bbox_extents(v_perax))[::-1]  # [3] desc

    for rank, rank_label in enumerate(['largest', 'middle', 'smallest']):
        rows2.append({
            'category': r['category'],
            'rank':     rank_label,
            'gt':       gt_sorted[rank],
            'iso':      ext_iso[rank],
            'peraxis':  ext_perax[rank],
            'iso_pct':    abs(ext_iso[rank]   - gt_sorted[rank]) / max(gt_sorted[rank], 1e-6) * 100,
            'peraxis_pct':abs(ext_perax[rank] - gt_sorted[rank]) / max(gt_sorted[rank], 1e-6) * 100,
        })

df2 = pd.DataFrame(rows2)

# Overall summary
# Per-sample MAPE (mean over 3 ranks)
per_sample_iso    = df2.groupby(df2.index // 3)['iso_pct'].mean()
per_sample_perax  = df2.groupby(df2.index // 3)['peraxis_pct'].mean()

print('=== Stage 2: Mesh Bounding Box MAPE ===')
print(f'  Isotropic  MAPE: {per_sample_iso.mean():.2f}%  (median {per_sample_iso.median():.2f}%)')
print(f'  Per-axis   MAPE: {per_sample_perax.mean():.2f}%  (median {per_sample_perax.median():.2f}%)')
print(f'  Gap (iso - peraxis): {per_sample_iso.mean() - per_sample_perax.mean():+.2f}pp')

print()
s2 = df2.groupby('rank').agg(
    iso_MAPE=('iso_pct', 'mean'),
    peraxis_MAPE=('peraxis_pct', 'mean'),
).round(2)
s2['gap_pp'] = (s2['iso_MAPE'] - s2['peraxis_MAPE']).round(2)
print(s2.to_string())
# Out:
# === Stage 2: Mesh Bounding Box MAPE ===
#   Isotropic  MAPE: 29.12%  (median 15.87%)
#   Per-axis   MAPE: 33.98%  (median 12.61%)
#   Gap (iso - peraxis): -4.85pp
#
#            iso_MAPE  peraxis_MAPE  gap_pp
# rank
# largest   23.930000         23.28    0.65
# middle    27.879999         43.23  -15.35
# smallest  35.549999         35.41    0.14

# %%
# --- Stage 2 scatter: mesh bbox dims vs GT dims (iso and per-axis) ---
rank_order  = ['largest', 'middle', 'smallest']
rank_labels = ['Largest axis', 'Middle axis', 'Smallest axis']

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
fig.suptitle('Stage 2: Scaled mesh bbox dim vs GT dim (rank-matched)', fontsize=13)

for col_idx, (rank, rank_label) in enumerate(zip(rank_order, rank_labels)):
    sub = df2[df2['rank'] == rank]

    for row_idx, (y_col, strategy) in enumerate([('iso', 'Isotropic'), ('peraxis', 'Per-axis')]):
        ax = axes[row_idx][col_idx]
        for cat in sub['category'].unique():
            grp = sub[sub['category'] == cat]
            col = CATEGORY_COLORS.get(cat, 'gray')
            ax.scatter(grp['gt'], grp[y_col], c=col, label=cat, alpha=0.75, s=50, edgecolors='none')
        lo = min(sub['gt'].min(), sub[y_col].min()) * 0.85
        hi = max(sub['gt'].max(), sub[y_col].max()) * 1.15
        ax.plot([lo, hi], [lo, hi], 'k--', lw=1)
        mape = sub[f'{y_col}_pct'].mean()
        ax.set_title(f'{strategy} — {rank_label}\nMAPE = {mape:.2f}%', fontsize=9)
        ax.set_xlabel('GT dim (m)', fontsize=8)
        ax.set_ylabel('Mesh bbox dim (m)', fontsize=8)
        ax.set_xlim(lo, hi); ax.set_ylim(lo, hi)
        ax.set_aspect('equal')
        if col_idx == 2 and row_idx == 0:
            ax.legend(fontsize=7, markerscale=0.9)

plt.tight_layout()
# plt.savefig('artifacts/metric_scale/eval_v3_notebook/stage2_scatter.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# --- Gap bar chart: iso vs per-axis MAPE per rank ---
fig, ax = plt.subplots(figsize=(9, 5))

x      = np.arange(3)
width  = 0.35
iso_means   = [df2[df2['rank'] == r]['iso_pct'].mean()    for r in rank_order]
perax_means = [df2[df2['rank'] == r]['peraxis_pct'].mean() for r in rank_order]

b1 = ax.bar(x - width/2, iso_means,   width, label='Isotropic',  color='#d95f02', alpha=0.85)
b2 = ax.bar(x + width/2, perax_means, width, label='Per-axis',   color='#1b9e77', alpha=0.85)

for bar in list(b1) + list(b2):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.2,
            f'{bar.get_height():.1f}%', ha='center', va='bottom', fontsize=9)

ax.set_xticks(x)
ax.set_xticklabels(['Largest axis', 'Middle axis', 'Smallest axis'])
ax.set_ylabel('Mean absolute percentage error (%)')
ax.set_title('Stage 2: Isotropic vs Per-axis mesh MAPE per rank')
ax.legend()
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
# plt.savefig('artifacts/metric_scale/eval_v3_notebook/stage2_gap_bars.png', dpi=150, bbox_inches='tight')
plt.show()

print(f'Aspect ratio gap (overall): {np.mean(iso_means) - np.mean(perax_means):+.2f}pp')
# Out:
# Aspect ratio gap (overall): -4.85pp

# %%
# --- Per-category breakdown (Stage 2) ---
cat_s2 = df2.groupby('category').agg(
    iso_MAPE   =('iso_pct',    'mean'),
    peraxis_MAPE=('peraxis_pct','mean'),
).round(2)
cat_s2['gap_pp'] = (cat_s2['iso_MAPE'] - cat_s2['peraxis_MAPE']).round(2)
cat_s2 = cat_s2.sort_values('gap_pp', ascending=False)
print('=== Stage 2: Per-category mesh MAPE ===')
print(cat_s2.to_string())

# Bar chart
fig, ax = plt.subplots(figsize=(10, 5))
cats = cat_s2.index.tolist()
x2   = np.arange(len(cats))
ax.bar(x2 - width/2, cat_s2['iso_MAPE'],    width, label='Isotropic',  color='#d95f02', alpha=0.85)
ax.bar(x2 + width/2, cat_s2['peraxis_MAPE'],width, label='Per-axis',   color='#1b9e77', alpha=0.85)
ax.set_xticks(x2)
ax.set_xticklabels(cats)
ax.set_ylabel('MAPE (%)')
ax.set_title('Stage 2: Mesh bbox MAPE by category  (iso vs per-axis)')
ax.legend()
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
# plt.savefig('artifacts/metric_scale/eval_v3_notebook/stage2_category_bars.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# === Stage 2: Per-category mesh MAPE ===
#            iso_MAPE  peraxis_MAPE  gap_pp
# category
# laptop    20.330000          2.41   17.92
# cup       42.180000         36.37    5.81
# bowl       8.390000          8.83   -0.44
# camera    80.550003         84.26   -3.71
# bottle    13.240000         24.31  -11.07
# can       20.680000         61.47  -40.79

# %%
# --- Canonical mesh shape: actual voxel aspect ratio vs GT ---
# Shows how far the SS mesh extents are from the GT proportions (before any scaling)

rows3 = []
for r in results:
    raw_ext    = mesh_bbox_extents(r['verts_canonical'])          # [3]
    raw_sorted = np.sort(raw_ext)[::-1].copy()                    # [3] desc
    gt_sorted  = np.sort(r['gt_dims'])[::-1].copy()               # [3] desc

    # Normalise both to max=1 for shape-only comparison
    raw_norm = raw_sorted / max(raw_sorted[0], 1e-6)
    gt_norm  = gt_sorted  / max(gt_sorted[0],  1e-6)

    for rank, rank_label in enumerate(['largest', 'middle', 'smallest']):
        rows3.append({
            'category': r['category'],
            'rank':     rank_label,
            'gt_norm':  gt_norm[rank],
            'raw_norm': raw_norm[rank],
            'pct_err':  abs(raw_norm[rank] - gt_norm[rank]) / max(gt_norm[rank], 1e-6) * 100,
        })

df3 = pd.DataFrame(rows3)

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Canonical mesh shape vs GT (max-normalised, largest axis = 1.0)', fontsize=12)

for ax, rank in zip(axes, rank_order):
    sub = df3[df3['rank'] == rank]
    for cat in sub['category'].unique():
        grp = sub[sub['category'] == cat]
        col = CATEGORY_COLORS.get(cat, 'gray')
        ax.scatter(grp['gt_norm'], grp['raw_norm'], c=col, label=cat, alpha=0.7, s=50, edgecolors='none')
    ax.plot([0, 1.1], [0, 1.1], 'k--', lw=1)
    ax.set_xlabel('GT normalised extent')
    ax.set_ylabel('Mesh normalised extent')
    mape = sub['pct_err'].mean()
    ax.set_title(f'{rank.capitalize()} axis  |  err = {mape:.1f}%')
    ax.set_xlim(0, 1.15); ax.set_ylim(0, 1.15)
    ax.set_aspect('equal')
    if rank == 'smallest':
        ax.legend(fontsize=7)

plt.tight_layout()
# plt.savefig('artifacts/metric_scale/eval_v3_notebook/canonical_shape.png', dpi=150, bbox_inches='tight')
plt.show()

print('Canonical mesh shape error (before any scaling):')
print(df3.groupby('rank')['pct_err'].mean().round(2).to_string())
# Out:
# Canonical mesh shape error (before any scaling):
# rank
# largest      0.00
# middle       8.69
# smallest    17.43

# %% [markdown]
# ---
# ## Summary

# %%
print('=' * 60)
print(f'CHECKPOINT: {os.path.basename(CHECKPOINT)}')
print(f'Samples:    {len(results)}')
print('=' * 60)

print('\n--- Stage 1: MetricScaleDecoder (pred [W,H,D] vs GT) ---')
for d in ['W', 'H', 'D']:
    mape = df1[df1['dim'] == d]['pct_err'].mean()
    print(f'  {d}: {mape:.2f}%')
print(f'  Overall: {df1["pct_err"].mean():.2f}%')

print('\n--- Stage 2: Mesh bbox (iso vs per-axis) ---')
print(f'  Isotropic MAPE:  {per_sample_iso.mean():.2f}%')
print(f'  Per-axis  MAPE:  {per_sample_perax.mean():.2f}%')
print(f'  Aspect ratio gap: {per_sample_iso.mean() - per_sample_perax.mean():+.2f}pp')

print('\n--- Stage 2 per category ---')
print(cat_s2[['iso_MAPE', 'peraxis_MAPE', 'gap_pp']].to_string())
print('=' * 60)
# Out:
# ============================================================
# CHECKPOINT: nocs_sceneholdout_ss_ratio_v1_best.pt
# Samples:    64
# ============================================================
#
# --- Stage 1: MetricScaleDecoder (pred [W,H,D] vs GT) ---
#   W: 52.54%
#   H: 42.95%
#   D: 19.39%
#   Overall: 38.29%
#
# --- Stage 2: Mesh bbox (iso vs per-axis) ---
#   Isotropic MAPE:  29.12%
#   Per-axis  MAPE:  33.98%
#   Aspect ratio gap: -4.85pp
#
# --- Stage 2 per category ---
#            iso_MAPE  peraxis_MAPE  gap_pp
# category
# laptop    20.330000          2.41   17.92
# cup       42.180000         36.37    5.81
# bowl       8.390000          8.83   -0.44
# camera    80.550003         84.26   -3.71
# bottle    13.240000         24.31  -11.07
# can       20.680000         61.47  -40.79
# ============================================================

# %%
# Save all results to JSONL for later analysis
import json
os.makedirs('artifacts/metric_scale/eval_v3_notebook-ratio', exist_ok=True)

out_path = 'artifacts/metric_scale/eval_v3_notebook-ratio/results.jsonl'
with open(out_path, 'w') as f:
    for r in results:
        row = {
            'category': r['category'],
            'gt_dims':   r['gt_dims'].tolist(),
            'pred_dims': r['pred_dims'].tolist(),
        }
        # Add mesh bbox metrics
        verts     = r['verts_canonical']
        pred_dims = r['pred_dims']
        gt_sorted = np.sort(r['gt_dims'])[::-1].tolist()
        v_iso  = apply_iso_scale(verts, pred_dims)
        v_perax = apply_peraxis_scale(verts, pred_dims)
        row['gt_sorted']     = gt_sorted
        row['bbox_iso']      = np.sort(mesh_bbox_extents(v_iso))[::-1].tolist()
        row['bbox_peraxis']  = np.sort(mesh_bbox_extents(v_perax))[::-1].tolist()
        f.write(json.dumps(row) + '\n')

print(f'Results saved to {out_path}')
# Out:
# Results saved to artifacts/metric_scale/eval_v3_notebook-ratio/results.jsonl
